# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.model_selection import train_test_split
import re
import statsmodels.api as sm
from sklearn import metrics
# %matplotlib inline

# %% [markdown]
# ## Importación Dataset

# %%
df = pd.read_csv('properatti.csv', index_col = 0) ### Dataset Completo
## DataFrame Partido en distintas partes relevantes
df_posicion_geografica = df.loc[:,['place_name','state_name','country_name','place_with_parent_names' \
                                   ,'geonames_id','lat','lon','lat-lon', \
                                   'describe','title']] ### Parte con Posición Geográfica
df_localidad=df.loc[:,['place_name','place_with_parent_names','describe','title']] ## Parte con Localidades
df_ambientes = df.loc[:,['rooms','property_type','description','title']]  ## Parte con Ambientes
df_pisos = df.loc[:,['floor','property_type','description','title']]  ## Parte con Pisos
df_precio = df.loc[:,['price','currency','price_aprox_local_currency','price_aprox_usd',\
                      'surface_total_in_m2','surface_covered_in_m2','price_usd_per_m2',\
                      'price_per_m2','description','title']]  ## Parte con Precios y Superficies
# Out:
# C:\Users\zelru\Anaconda3\lib\site-packages\pandas\core\indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %% [markdown]
# ## Funciones

# %%
def crear_serie_precio(x):
    if not np.isnan(np.array(x.precio_en_titulo)):
        return x.precio_en_titulo
    elif not np.isnan(np.array(x.price_aprox_usd)):
        return x.price_aprox_usd
    else:
        return np.NaN
def crear_serie_ambientes(x):
    if not np.isnan(np.array(x.rooms_description)):
        return x.rooms_description
    if not np.isnan(np.array(x['rooms_title'])):
        return x['rooms_title']
    if not np.isnan(np.array(x.rooms)):
        return x.rooms
    return np.NaN
def detectar_ambientes(x):
    y = busqueda_monoambientes(x)
    if np.isnan(np.array(y)):
        y=busqueda_ambientes(x)
    if np.isnan(np.array(y)):
        y=busqueda_por_texto(x)
    return y
def update(df,column,s):
    '''
    Reemplaza los valores de la columna del DataFrame con
    los valores no nulos de la serie
    '''
    df[column]=s.fillna(df[column])
    return df

def busqueda_ambientes(x):
    '''
    Busca la palabra amb (de ambientes) y devuelve el número que tiene por delante
    '''
    try:
        pattern = '(\d+)\s*amb'
        regex = re.compile(pattern, flags = re.IGNORECASE | re.UNICODE)
        m = regex.search(x)
        if m:
            valor =float(m.group(1))
            if valor < 8:
                return valor
            else:
                return 1.0
        else:
            return np.NaN
    except:
        return np.NaN

def busqueda_monoambientes(x):
    '''
    Busca en la palabra monoambiente y devuelve 1
    '''
    if type(x) is str:
        if x.lower().find('monoambiente') >-1:
            return 1.0
        else:
            return np.NaN
    else:
        return np.NaN
def busqueda_moneda(x):
    try:
        pattern = 'U\$D\s*([\d\.]+)'
        regex = re.compile(pattern, flags = re.IGNORECASE | re.UNICODE)
        m = regex.search(x)
        if m:
            return float(m.group(1).replace('.',''))
        else:
            np.NaN
    except:
        return np.NaN
    
def parsear_numeros(x):
    '''
    Reemplaza numeros escritos en letras por sus equivalentes
    en arábigos.
    '''
    try:
        numeros={'uno':1,'un':1,'una':1,'dos':2,'tres':3,'cuatro':4,'cinco':5,'seis':6,'siete':7,'ocho':8,'nueve':9,'diez':10}
        for key in numeros:
            x = x.lower()
            x=x.replace(key,str(numeros[key]))
        return x
    except:
        return x

def busqueda_por_texto(x):
    '''
    Busca palabras claves asociadas a ambientes, como dormitorio, comedor, living, etc.
    y devuelve el número de veces que estas aparecen.
    '''
    result = 0.0
    valor = 0.0
    try:
        pattern = r"(\d*\s*living\s*cocina\s*comedor|living\s*comedor|living)|(\d*\s*dormitorio)|(\d*\s*comedor)"
        regex = re.compile(pattern, flags = re.IGNORECASE | re.UNICODE)
        grupos = regex.findall(x)
        for grupo in grupos:
            for elemento in grupo:
                regex_dos = re.compile(r'(\d+)', flags = re.IGNORECASE | re.UNICODE)
                cantidad = regex_dos.search(elemento)
                if cantidad is not None:
                    nuevo_valor = float(cantidad.group())
                    if nuevo_valor < 8:
                        valor+=nuevo_valor
            if result == valor:
                result+=1
                valor+=1
            else:
                result=valor
        if result > 0.0:
            return result
        else:
            return np.NaN
    except:
        return np.NaN
def convert_to_int(x):
    return int(x)
def busqueda_moneda(x):
    try:
        pattern = 'U\$D\s*([\d\.]+)'
        regex = re.compile(pattern, flags = re.IGNORECASE | re.UNICODE)
        m = regex.search(x)
        if m:
            return float(m.group(1).replace('.',''))
        else:
            np.NaN
    except:
        return np.NaN

# %% [markdown]
# # Parte Ambientes

# %% [markdown]
# * Descripción

# %%
df_ambientes.isnull().sum()
# Out:
# rooms            73830
# property_type        0
# description          2
# title                0
# dtype: int64

# %% [markdown]
# * Limpieza de Datos

# %%
df_ambientes_limpio = df_ambientes
df_ambientes_limpio.description=df_ambientes_limpio.description.apply(parsear_numeros)## Reemplaza los números escritos en letras por los arábigos
df_ambientes_limpio.title = df_ambientes_limpio.title.apply(parsear_numeros)
df_ambientes_limpio['rooms_title'] = df_ambientes.title.apply(detectar_ambientes)
df_ambientes_limpio['rooms_description'] = df_ambientes.description.apply(detectar_ambientes)
rooms = df_ambientes.apply(crear_serie_ambientes,1)
## Usar la Serie Rooms

# %%
df_limpio = pd.DataFrame({'Tipo de Propiedad':df.property_type,'Ambientes':rooms,'Titulo':df.title,'Descripcion':df.description})

# %% [markdown]
# ``` Estado del DataSet al momento ```

# %%
df_limpio.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001EA513AD9B0>]],
#       dtype=object)

# %% [markdown]
# # Parte Precios

# %%
df_precio.isnull().sum()
## El DataSet nos trae los precios, precios evaluados en ARS y en USD. Usamos los Dolares y nos olvidamos del resto
# Out:
# price                         20410
# currency                      20411
# price_aprox_local_currency    20410
# price_aprox_usd               20410
# surface_total_in_m2           39328
# surface_covered_in_m2         19907
# price_usd_per_m2              52603
# price_per_m2                  33562
# description                       2
# title                             0
# dtype: int64

# %%
set(df_precio.currency)
##Hay valores en Pesos, en Uruguayos, en Peruanos y en Dólares
# Out:
# {'ARS', 'PEN', 'USD', 'UYU', nan}

# %%
df_precio[df_precio.currency =='PEN']
## Los registros que tienen precios en Soles, segun esto pertenece a la Arg
# Out:
#           price currency  price_aprox_local_currency  price_aprox_usd  \
# 50387  380000.0      PEN                  2066864.90        117139.33
# 50388  950000.0      PEN                  5167162.35        292848.33
#
#        surface_total_in_m2  surface_covered_in_m2  price_usd_per_m2  \
# 50387                  NaN                    NaN               NaN
# 50388                  NaN                    NaN               NaN
#
#        price_per_m2                                        description  \
# 50387           NaN  Ref.: 55:PREVENTA ::: OPORTUNIDAD ::: Dúplex a...
# 50388           NaN  Ref.: 56Duplex en venta de 1 dormitorio con ap...
#
#                                            title
# 50387  DUPLEX A LA VENTA | Liniers 1200 | Tandil
# 50388  DUPLEX A LA VENTA | Liniers 1200 | Tandil

# %%
df_precio[df_precio.currency =='UYU']
## Segun la descripcion, este esta en Mendoza.
# Out:
#               price currency  price_aprox_local_currency  price_aprox_usd  \
# 107390  650000000.0      UYU                4.054773e+08      22980378.29
#
#         surface_total_in_m2  surface_covered_in_m2  price_usd_per_m2  \
# 107390                  NaN                    NaN               NaN
#
#         price_per_m2                                        description  \
# 107390           NaN  Casa con Calefacción central, Mendoza, San Roq...
#
#                      title
# 107390  Casa - San Vicente

# %%
df_precio['precio_en_titulo'] = df_precio.title.apply(busqueda_moneda)
precio = df_precio.apply(crear_serie_precio,1)

# %%
precio.isnull().sum()
# Out:
# 17982

# %%
df_precio[df_precio.description.str.contains('USD').isnull()]
## Ya tienen el precio, no me interesa mirarlos por dentro
# Out:
#            price currency  price_aprox_local_currency  price_aprox_usd  \
# 10664  2350000.0      ARS                  2325485.81        131796.64
# 96691    98000.0      USD                  1729161.00         98000.00
#
#        surface_total_in_m2  surface_covered_in_m2  price_usd_per_m2  \
# 10664                  NaN                    NaN               NaN
# 96691                  NaN                   55.0               NaN
#
#        price_per_m2 description                                        title  \
# 10664           NaN         NaN  HERMOSO DEPARTAMENTO CON PISCINA Y COCHERA
# 96691   1781.818182         NaN                  Departamento - San Fernando
#
#        precio_en_titulo
# 10664               NaN
# 96691               NaN

# %%
df_precio.title.str.contains('dolar').isnull().sum()
# Out:
# 0

# %% [markdown]
# - Los datos sin precios los eliminamos

# %%
x=11
df_precio[df_precio.currency.isnull()].iloc[x,-1],df_precio[df_precio.currency.isnull()].iloc[x,-2]
# Out:
# (nan,
#  'Rosario - Tucuman 3400 - Venta Dptos 2 Dormitorios en construcción - InmGazze')

# %% [markdown]
# # Parte Superficie

# %% [markdown]
# - Por una cuestión de tiempo solo invertimos aquellos casos donde la superficie cubierta era mayor que la total, debería hacerce una busqueda en description o en title en aquellos casos que estén vacíos.

# %%
Superficie = df_precio.apply(lambda x: pd.Series([x.surface_covered_in_m2,x.surface_total_in_m2]) 
                       if x.surface_covered_in_m2 <= x.surface_total_in_m2
                       else pd.Series([x.surface_total_in_m2,x.surface_covered_in_m2]) ,1)

# %%
Superficie.columns = ['surface_covered_in_m2','surface_total_in_m2']

# %%
#Superficie = Superficie.apply(lambda x: pd.Series([x.surface_covered_in_m2,x.surface_covered_in_m2])
#                      if x.surface_covered_in_m2 is None and x.surface_total_in_m2 is not None
#                       else (pd.Series([x.surface_total_in_m2,x.surface_total_in_m2])
#                       if x.surface_covered_in_m2 is not None and x.surface_total_in_m2 is None
#
#else pd.Series([x.surface_covered_in_m2,x.surface_total_in_m2])) ,1)

# %%
Superficie.surface_covered_in_m2.fillna(Superficie.surface_total_in_m2,inplace=True)
Superficie.surface_total_in_m2.fillna(Superficie.surface_covered_in_m2,inplace=True)

# %%
Superficie.columns = ['Superficie Cubierta','Superficie Total']

# %%
## Reagrupamos la Info

# %%
df_limpio['Superficie Cubierta']=Superficie['Superficie Cubierta']
df_limpio['Superficie Total'] = Superficie['Superficie Total']

# %%
df_limpio=df_limpio[['Tipo de Propiedad','Ambientes','Superficie Cubierta','Superficie Total','Titulo','Descripcion']]
df_limpio.sample(5)
# Out:
#       Tipo de Propiedad  Ambientes  Superficie Cubierta  Superficie Total  \
# 13709             house        3.0                246.0             246.0
# 93138             house        4.0                123.0             123.0
# 6869              house        3.0                150.0             210.0
# 56941             house        5.0                205.0             205.0
# 66335         apartment        NaN                 53.0              61.0
#
#                                               Titulo  \
# 13709       APTA CREDITO!CASA EN VILLA ALLENDE PARQU
# 93138                               Casa en Victoria
# 6869       Chalet en Venta Haedo / Moron (A007 1859)
# 56941  Casa mas 2 locales en La Rioja y 3 de febrero
# 66335                       Departamento en Recoleta
#
#                                              Descripcion
# 13709                Casa en Venta de 3 dorm. en Cordoba
# 93138  Complejo Los Fresnos. UF Nº 20.Triplex a estre...
# 6869   Chalet tipo duplex, sobre lote de 6x35, 4 ampl...
# 56941  Interesante casa mas locales para diferentes a...
# 66335  Excelente esquina con unidades de vivienda apt...

# %% [markdown]
# # Parte Posición Geográfica

# %%
df_localidad_ex = pd.DataFrame(item for item in df_posicion_geografica.place_with_parent_names.str.split('|'))
df_localidad_ex.isnull().sum()
##Las variables de "zona" 4,5 y 6 estan muy incompletas. la mas recuperable es la 4
#df_posicion_geografica['pais_ex'] = df_localidad_ex[1]
#df_posicion_geografica['provincia_ex'] = df_localidad_ex[2]
#df_posicion_geografica['localidad_ex'] = df_localidad_ex[3]
#df_posicion_geografica['barrio_ex'] = df_localidad_ex[4]
#df_posicion_geografica['zona_ex'] = df_localidad_ex[5]
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4      4780
# 5     80780
# 6    120672
# dtype: int64

# %%
set(df_localidad_ex[1]) #Categorias de pais
# Out:
# {'Argentina'}

# %%
set(df_localidad_ex[2]) #Categoria de provincia, BSAS esta dividida en 5 partes
# Out:
# {'Bs.As. G.B.A. Zona Norte',
#  'Bs.As. G.B.A. Zona Oeste',
#  'Bs.As. G.B.A. Zona Sur',
#  'Buenos Aires Costa Atlántica',
#  'Buenos Aires Interior',
#  'Capital Federal',
#  'Catamarca',
#  'Chaco',
#  'Chubut',
#  'Corrientes',
#  'Córdoba',
#  'Entre Ríos',
#  'Formosa',
#  'Jujuy',
#  'La Pampa',
#  'La Rioja',
#  'Mendoza',
#  'Misiones',
#  'Neuquén',
#  'Río Negro',
#  'Salta',
#  'San Juan',
#  'San Luis',
#  'Santa Cruz',
#  'Santa Fe',
#  'Santiago Del Estero',
#  'Tierra Del Fuego',
#  'Tucumán'}

# %%
set(df_localidad_ex[3]) #Localidad
# Out:
# {'',
#  'Abasto',
#  'Achiras',
#  'Adolfo Alsina',
#  'Agronomía',
#  'Agua Blanca',
#  'Agua de Oro',
#  'Aguas Verdes',
#  'Aldea Brasilera',
#  'Aldea Salto',
#  'Alejandro Roca',
#  'Almafuerte',
#  'Almagro',
#  'Almirante Brown',
#  'Alta Gracia',
#  'Aluminé',
#  'Alvear',
#  'Anisacate',
#  'Apóstoles',
#  'Arequito',
#  'Arocena',
#  'Arroyo Ceibal',
#  'Arroyo Leyes',
#  'Arroyo Seco',
#  'Ascochinga',
#  'Ataliva',
#  'Avellaneda',
#  'Azara',
#  'Azul',
#  'Bahía Blanca',
#  'Balcarce',
#  'Balnearia',
#  'Balvanera',
#  'Banda del Río Salí',
#  'Baradero',
#  'Barracas',
#  'Barranqueras',
#  'Barrio Norte',
#  'Belgrano',
#  'Bell Ville',
#  'Bella Italia',
#  'Bella Vista',
#  'Berazategui',
#  'Berisso',
#  'Bernardo de Irigoyen',
#  'Bialet Massé',
#  'Boca',
#  'Boedo',
#  'Bouwer',
#  'Brandsen',
#  'Buena Nueva',
#  'Cabalango',
#  'Caballito',
#  'Cafayate',
#  'Caleta Olivia',
#  'Calmayo',
#  'Camet',
#  'Campana',
#  'Campo Grande',
#  'Campo Quijano',
#  'Candelaria',
#  'Capilla del Monte',
#  'Capilla del Rosario',
#  'Capitán Bermúdez',
#  'Capitán Sarmiento',
#  'Cariló',
#  'Carlos Casares',
#  'Carmen de Areco',
#  'Carolina',
#  'Carpintería',
#  'Casa Grande',
#  'Caseros',
#  'Castellanos',
#  'Catalinas',
#  'Cayastá',
#  'Cañadón Seco',
#  'Cañuelas',
#  'Centenario',
#  'Centro / Microcentro',
#  'Cerrillos',
#  'Cerro Azul',
#  'Chacarita',
#  'Chacras de Coria',
#  'Chajarí',
#  'Chapadmalal',
#  'Chascomús',
#  'Chimbas',
#  'Chivilcoy',
#  'Choele Choel',
#  'Cinco Saltos',
#  'Cipolletti',
#  'Claromecó',
#  'Coghlan',
#  'Colastiné',
#  'Colegiales',
#  'Colonia Benitez',
#  'Colonia Caroya',
#  'Colonia Elía',
#  'Colonia Tirolesa',
#  'Colón',
#  'Comodoro Rivadavia',
#  'Concepción',
#  'Concepción del Uruguay',
#  'Concordia',
#  'Confluencia',
#  'Congreso',
#  'Constitución',
#  'Corcovado',
#  'Coronda',
#  'Coronel Bogado',
#  'Coronel Dorrego',
#  'Coronel Du Graty',
#  'Coronel Moldes',
#  'Coronel Suárez',
#  'Corrientes',
#  'Cosquín',
#  'Costa Azul',
#  'Costa Esmeralda',
#  'Costa Uruguay Sur',
#  'Costa del Este',
#  'Cruz del Eje',
#  'Cushamen',
#  'Córdoba',
#  'Desamparados',
#  'Despeñaderos',
#  'Desvío Arijón',
#  'Dina Huapi',
#  'Dorrego',
#  'Dunamar',
#  'El Calafate',
#  'El Chaltén',
#  'El Dorado',
#  'El Manzano',
#  'El Sauce',
#  'El Trapiche',
#  'El Volcán',
#  'Embalse',
#  'Emilia',
#  'Empalme Villa Constitución',
#  'Ensenada',
#  'Escalante',
#  'Escobar',
#  'Esperanza',
#  'Esquel',
#  'Esteban Echeverría',
#  'Exaltación de la Cruz',
#  'Ezeiza',
#  'Falda del Carmen',
#  'Federación',
#  'Felicia',
#  'Fighiera',
#  'Florencio Varela',
#  'Flores',
#  'Floresta',
#  'Formosa',
#  'Franck',
#  'Fray Luis Beltrán',
#  'Funes',
#  'Gaiman',
#  'Garuhapé',
#  'Garupá',
#  'General Alvarado',
#  'General Alvear',
#  'General Belgrano',
#  'General Cabrera',
#  'General Fernández Oro',
#  'General Lagos',
#  'General Las Heras',
#  'General Lavalle',
#  'General Madariaga',
#  'General Paz',
#  'General Pico',
#  'General Pinto',
#  'General Pueyrredón',
#  'General Roca',
#  'General Rodríguez',
#  'General San Martín',
#  'Gobernador Benegas',
#  'Godoy Cruz',
#  'Granadero Baigorria',
#  'Gualeguaychú',
#  'Gálvez',
#  'Güer Aike',
#  'Helvecia',
#  'Hernando',
#  'Hoyo de Epuyén',
#  'Huerta Grande',
#  'Humboldt',
#  'Hurlingham',
#  'Ibarlucea',
#  'Intendente Alvear',
#  'Iriondo',
#  'Ituzaingó',
#  'J A de la Peña',
#  'Jesús María',
#  'José C Paz',
#  'Juana Koslay',
#  'Junin de los Andes',
#  'Junín',
#  'La Caldera',
#  'La Calera',
#  'La Cumbre',
#  'La Cumbrecita',
#  'La Falda',
#  'La Granja',
#  'La Lucila del Mar',
#  'La Matanza',
#  'La Paz',
#  'La Plata',
#  'La Punilla',
#  'La Punta',
#  'La Rioja',
#  'La Serranita',
#  'La Silleta',
#  'Laboulaye',
#  'Lago Epuyén',
#  'Laguna Larga',
#  'Laguna Paiva',
#  'Lanús',
#  'Laprida',
#  'Las Calles',
#  'Las Cañitas',
#  'Las Gaviotas',
#  'Las Grutas',
#  'Las Heras',
#  'Las Palmas',
#  'Las Parejas',
#  'Las Rosas',
#  'Las Talitas',
#  'Las Tapias',
#  'Las Toninas',
#  'Las Varillas',
#  'Lincoln',
#  'Liniers',
#  'Lobería',
#  'Lobos',
#  'Lomas de Zamora',
#  'Los Cipreses',
#  'Los Cocos',
#  'Los Corralitos',
#  'Los Hornillos',
#  'Los Laureles',
#  'Los Molinos',
#  'Los Pozos',
#  'Los Reartes',
#  'Luis Beltrán',
#  'Luján',
#  'Luján de Cuyo',
#  'Lules',
#  'Luque',
#  'Lácar',
#  'Magdalena',
#  'Maipú',
#  'Malabrigo',
#  'Malagueño',
#  'Malargüe',
#  'Malvinas Argentinas',
#  'Manantiales',
#  'Manfredi',
#  'Mar Azul',
#  'Mar Chiquita',
#  'Mar de Ajó',
#  'Mar de Cobo',
#  'Mar de las Pampas',
#  'Mar del Plata',
#  'Mar del Sur',
#  'Mar del Tuyú',
#  'Marcos Paz',
#  'Marull',
#  'María Grande',
#  'María Juana',
#  'Mataderos',
#  'Mayor Drummond',
#  'Mayu Sumaj',
#  'Mburucuyá',
#  'Mendiolaza',
#  'Mendoza',
#  'Mercedes',
#  'Merlo',
#  'Mi Granja',
#  'Mina Clavero',
#  'Miramar',
#  'Monje',
#  'Monserrat',
#  'Monte Castro',
#  'Monte Cristo',
#  'Monte Hermoso',
#  'Monte Vera',
#  'Moreno',
#  'Morón',
#  'Murphy',
#  'Navarro',
#  'Necochea',
#  'Nelson',
#  'Neuquén',
#  'Nogoyá',
#  'Nono',
#  'Nueva Atlantis',
#  'Nueva Ciudad',
#  'Nueve de Julio',
#  'Nuñez',
#  'Oberá',
#  'Obispo Trejo',
#  'Olavarría',
#  'Oliva',
#  'Oliveros',
#  'Oncativo',
#  'Once',
#  'Oro Verde',
#  'Ostende',
#  'Palermo',
#  'Pampa del Infierno',
#  'Paraná',
#  'Parque Avellaneda',
#  'Parque Centenario',
#  'Parque Chacabuco',
#  'Parque Chas',
#  'Parque Patricios',
#  'Paso de la Patria',
#  'Paso de los Libres',
#  'Patagones',
#  'Paternal',
#  'Pedro Molina',
#  'Pehuajó',
#  'Pehuen-có',
#  'Pergamino',
#  'Perú',
#  'Pilar',
#  'Pinamar',
#  'Pinto',
#  'Playa Unión',
#  'Plottier',
#  'Pompeya',
#  'Posadas',
#  'Potrerillos',
#  'Potrero de Garay',
#  'Potrero de los Funes',
#  'Presidencia Roque Sáenz Peña',
#  'Presidente Perón',
#  'Presidente Roca',
#  'Providencia',
#  'Pueblo Andino',
#  'Pueblo Esther',
#  'Pueblo Liebig',
#  'Puerto Esperanza',
#  'Puerto Iguazú',
#  'Puerto Libertad',
#  'Puerto Madero',
#  'Puerto Madryn',
#  'Pujato Norte',
#  'Punilla',
#  'Punta Alta',
#  'Punta Indio',
#  'Pérez',
#  'Quemú Quemú',
#  'Quilmes',
#  'Rada Tilly',
#  'Rafaela',
#  'Ramallo',
#  'Rancagua',
#  'Rawson',
#  'Recoleta',
#  'Reconquista',
#  'Recreo',
#  'Renca',
#  'Resistencia',
#  'Reta',
#  'Retiro',
#  'Ricardone',
#  'Rincón de los Sauces',
#  'Rivadavia',
#  'Rodeo de la Cruz',
#  'Roldán',
#  'Roque Pérez',
#  'Rosario',
#  'Rosario de Lerma',
#  'Rufino',
#  'Río Ceballos',
#  'Río Cuarto',
#  'Río Gallegos',
#  'Río Grande',
#  'Río Primero',
#  'Río Segundo',
#  'Río Tercero',
#  'Río de Los Sauces',
#  'Saavedra',
#  'Saldán',
#  'Salsipuedes',
#  'Salta',
#  'San Andrés de Giles',
#  'San Antonio',
#  'San Antonio de Areco',
#  'San Antonio de Arredondo',
#  'San Benito',
#  'San Bernardo',
#  'San Carlos',
#  'San Carlos Centro',
#  'San Carlos de Bariloche',
#  'San Cayetano',
#  'San Clemente',
#  'San Clemente del Tuyú',
#  'San Cristobal',
#  'San Cristóbal',
#  'San Esteban',
#  'San Fernando',
#  'San Fernando del Valle de Catamarca',
#  'San Francisco',
#  'San Francisco del Monte',
#  'San Isidro',
#  'San Javier',
#  'San Javier/Yacanto',
#  'San Jerónimo Norte',
#  'San Jorge',
#  'San José',
#  'San José del Rincón',
#  'San Juan',
#  'San Justo',
#  'San Lorenzo',
#  'San Luis',
#  'San Martín',
#  'San Martín de los Andes',
#  'San Miguel',
#  'San Miguel de Tucumán',
#  'San Miguel del Monte',
#  'San Nicolás',
#  'San Nicolás de los Arroyos',
#  'San Pedro',
#  'San Rafael',
#  'San Ramón de la Nueva Orán',
#  'San Roque',
#  'San Salvador de Jujuy',
#  'San Telmo',
#  'San Vicente',
#  'Santa Ana',
#  'Santa Catalina',
#  'Santa Clara del Mar',
#  'Santa Fe',
#  'Santa Lucía',
#  'Santa Luisa',
#  'Santa María',
#  'Santa Rosa',
#  'Santa Rosa de Calamuchita',
#  'Santa Rosa de Calchines',
#  'Santa Teresa',
#  'Santa Teresita',
#  'Santo Tomé',
#  'Sarmiento',
#  'Sauce Viejo',
#  'Serodino',
#  'Sinsacate',
#  'Speluzzi',
#  'Suipacha',
#  'Sunchales',
#  'Susana',
#  'Tafí Viejo',
#  'Tafí del Valle',
#  'Tancacha',
#  'Tandil',
#  'Tanti',
#  'Tigre',
#  'Tilisarao',
#  'Timbúes',
#  'Toay',
#  'Toledo',
#  'Tornquist',
#  'Trelew',
#  'Trenel',
#  'Trenque Lauquen',
#  'Tres Arroyos',
#  'Tres de Febrero',
#  'Trevelín',
#  'Tribunales',
#  'Trinidad',
#  'Tunuyán',
#  'Unquillo',
#  'Ushuaia',
#  'Uspallata',
#  'Valeria del Mar',
#  'Valle Hermoso',
#  'Veinticinco de Mayo',
#  'Velez Sarsfield',
#  'Venado Tuerto',
#  'Versalles',
#  'Vicente López',
#  'Victoria',
#  'Viedma',
#  'Villa Allende',
#  'Villa Amancay',
#  'Villa Belgrano',
#  'Villa Carlos Paz',
#  'Villa Cerro Azul',
#  'Villa Ciudad Parque Los Reartes',
#  'Villa Ciudad de América',
#  'Villa Constitución',
#  'Villa Crespo',
#  'Villa Cura Brochero',
#  'Villa Devoto',
#  'Villa Dolores',
#  'Villa Elisa',
#  'Villa Fontana',
#  'Villa General Belgrano',
#  'Villa General Mitre',
#  'Villa Gesell',
#  'Villa Giardino',
#  'Villa Icho Cruz',
#  'Villa La Angostura',
#  'Villa La Bolsa',
#  'Villa Larca',
#  'Villa Llao Llao',
#  'Villa Los Aromos',
#  'Villa Lugano',
#  'Villa Luro',
#  'Villa María',
#  'Villa Mercedes',
#  'Villa Nueva',
#  'Villa Ortuzar',
#  'Villa Paranacito',
#  'Villa Parque Santa Ana',
#  'Villa Parque Siquiman',
#  'Villa Pueyrredón',
#  'Villa Real',
#  'Villa Riachuelo',
#  'Villa Rumipal',
#  'Villa Santa Cruz del Lago',
#  'Villa Santa Rita',
#  'Villa Soldati',
#  'Villa Unión',
#  'Villa Urquiza',
#  'Villa de Las Rosas',
#  'Villa de Soto',
#  'Villa del Dique',
#  'Villa del Parque',
#  'Villa del Totoral',
#  'Villarino',
#  'Vistalba',
#  'Wenceslao Escalante',
#  'Yerba Buena',
#  'Zárate',
#  'Álvarez'}

# %%
len(set(df_localidad_ex[4])) #Barrio
# Out:
# 569

# %%
set(df_localidad_ex[5])
# Out:
# {'',
#  'Barrio Barrancas del Lago',
#  'Barrio Cabos del Lago',
#  'Barrio El Golf',
#  'Barrio El Yacht',
#  'Barrio La Alameda',
#  'Barrio La Isla',
#  'Barrio Las Glorietas',
#  'Barrio Los Alisos',
#  'Barrio Los Castores',
#  'Barrio Los Lagos',
#  'Barrio Los Sauces',
#  'Barrio Los Tilos',
#  'BarrioPortezuelo',
#  'Enyoi',
#  'Islas del Canal',
#  None,
#  'QBay Yacht'}

# %%
set(df_localidad_ex[6]) #datos vacios
# Out:
# {'', None}

# %%
df_localidad_ex[df_localidad_ex[4] =='coordenadas 34.255511'] 
df_localidad_ex.iloc[7367,4] ='Nordelta'
## El registro 7367 es el unico que tiene este campo y esta en Nordelta segun Properatti

# %%
print('Vacios: ',len(df_localidad_ex[(df_localidad_ex[4] == '') | (df_localidad_ex[4].isnull())][4]))
print('Con datos:',len(df_localidad_ex)-len(df_localidad_ex[(df_localidad_ex[4] == '') | (df_localidad_ex[4].isnull())][4]))

## Hay 80803 vacios, lo mas facil seria tirarlo, lo ideal seria buscar por la lat/lon de donde viene realmente, pero no tenemos
## datos para todos ni el tiempo para hacerlo, en vez de eso lo que hacemos es pegarle a los vacios y los nulos el dato de
## la localidad, que sigue un criterio parecido al que tiene el dataset
# Out:
# Vacios:  80803
# Con datos: 40417

# %%
df_posicion_geografica['pais_ex'] = df_localidad_ex[1]
df_posicion_geografica['provincia_ex'] = df_localidad_ex[2]
df_posicion_geografica['localidad_ex'] = df_localidad_ex[3]
df_posicion_geografica['barrio_ex'] = df_localidad_ex[4]

# %%
df_posicion_geografica.place_name.fillna(df_posicion_geografica.localidad_ex,inplace=True)

# %%
df_posicion_geografica[df_posicion_geografica.place_name !=df_posicion_geografica.localidad_ex].head()
##Hay muchas areas en las que no coinciden el place name con la localidad a la que encontramos que pertenece
##En muchos casos coinciden con algun barrio/zona del daaset
# Out:
#       place_name                    state_name country_name  \
# 4         Centro  Buenos Aires Costa Atlántica    Argentina
# 6          Munro      Bs.As. G.B.A. Zona Norte    Argentina
# 12      Martínez      Bs.As. G.B.A. Zona Norte    Argentina
# 13  Palermo Soho               Capital Federal    Argentina
# 14  Palermo Soho               Capital Federal    Argentina
#
#                               place_with_parent_names  geonames_id        lat  \
# 4   |Argentina|Buenos Aires Costa Atlántica|Mar de...    3435548.0 -38.002626
# 6   |Argentina|Bs.As. G.B.A. Zona Norte|Vicente Ló...    3430511.0 -34.532957
# 12  |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...    3430813.0 -34.486019
# 13   |Argentina|Capital Federal|Palermo|Palermo Soho|    3430234.0        NaN
# 14   |Argentina|Capital Federal|Palermo|Palermo Soho|    3430234.0        NaN
#
#           lon                  lat-lon  describe  \
# 4  -57.549447  -38.0026256,-57.5494468       NaN
# 6  -58.521782  -34.5329567,-58.5217825       NaN
# 12 -58.503814  -34.4860195,-58.5038139       NaN
# 13        NaN                      NaN       NaN
# 14        NaN                      NaN       NaN
#
#                                                 title    pais_ex  \
# 4   DEPTO 2 AMB AL CONTRAFRENTE ZONA CENTRO/PLAZA ...  Argentina
# 6   MUY BUEN PH AL FRENTE DOS DORMITORIOS , PATIO,...  Argentina
# 12  EXCELENTE DEPARTAMENTO 2 AMBIENTES CONTRAFRENT...  Argentina
# 13                                    Vitraux Palermo  Argentina
# 14                                    Vitraux Palermo  Argentina
#
#                     provincia_ex   localidad_ex     barrio_ex
# 4   Buenos Aires Costa Atlántica  Mar del Plata        Centro
# 6       Bs.As. G.B.A. Zona Norte  Vicente López         Munro
# 12      Bs.As. G.B.A. Zona Norte     San Isidro      Martínez
# 13               Capital Federal        Palermo  Palermo Soho
# 14               Capital Federal        Palermo  Palermo Soho

# %%
len(df_posicion_geografica[df_posicion_geografica.place_name !=df_posicion_geografica.localidad_ex])
#Hay 35170 datos que no coinciden
# Out:
# 35170

# %%
df_posicion_geografica.barrio_ex =df_posicion_geografica.apply(lambda x: x.localidad_ex 
                                       if x.barrio_ex == '' or x.barrio_ex ==None 
                                       else x.barrio_ex,1)

# %%
df_posicion_geografica[df_posicion_geografica.barrio_ex == ''].title.iloc[0]
# Out:
# 'Casa 180m² con 2 Plantas en Navarro, Julián 2900, Argentina, Capital Federal, por U$S 170.000'

# %%
df_posicion_geografica.head()
# Out:
#   place_name                    state_name country_name  \
# 0  Mataderos               Capital Federal    Argentina
# 1   La Plata        Bs.As. G.B.A. Zona Sur    Argentina
# 2  Mataderos               Capital Federal    Argentina
# 3    Liniers               Capital Federal    Argentina
# 4     Centro  Buenos Aires Costa Atlántica    Argentina
#
#                              place_with_parent_names  geonames_id        lat  \
# 0              |Argentina|Capital Federal|Mataderos|    3430787.0 -34.661824
# 1        |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    3432039.0 -34.903883
# 2              |Argentina|Capital Federal|Mataderos|    3430787.0 -34.652262
# 3                |Argentina|Capital Federal|Liniers|    3431333.0 -34.647797
# 4  |Argentina|Buenos Aires Costa Atlántica|Mar de...    3435548.0 -38.002626
#
#          lon                  lat-lon  describe  \
# 0 -58.508839  -34.6618237,-58.5088387       NaN
# 1 -57.964330  -34.9038831,-57.9643295       NaN
# 2 -58.522982  -34.6522615,-58.5229825       NaN
# 3 -58.516424  -34.6477969,-58.5164244       NaN
# 4 -57.549447  -38.0026256,-57.5494468       NaN
#
#                                                title    pais_ex  \
# 0                 2 AMB TIPO CASA SIN EXPENSAS EN PB  Argentina
# 1  VENTA Depto 2 dorm. a estrenar 7 e/ 36 y 37   ...  Argentina
# 2           2 AMB 3ER PISO CON ASCENSOR APTO CREDITO  Argentina
# 3                       PH 3 amb. cfte. reciclado     Argentina
# 4  DEPTO 2 AMB AL CONTRAFRENTE ZONA CENTRO/PLAZA ...  Argentina
#
#                    provincia_ex   localidad_ex  barrio_ex
# 0               Capital Federal      Mataderos  Mataderos
# 1        Bs.As. G.B.A. Zona Sur       La Plata   La Plata
# 2               Capital Federal      Mataderos  Mataderos
# 3               Capital Federal        Liniers    Liniers
# 4  Buenos Aires Costa Atlántica  Mar del Plata     Centro

# %%
df_limpio['Pais'] = df_posicion_geografica['pais_ex']
df_limpio['Provincia'] = df_posicion_geografica['provincia_ex']
df_limpio['Localidad'] = df_posicion_geografica['localidad_ex']
df_limpio['Barrio'] = df_posicion_geografica['barrio_ex']

# %%
df_limpio=df_limpio[['Tipo de Propiedad','Ambientes','Superficie Cubierta','Superficie Total','Pais','Provincia','Localidad','Barrio','Titulo','Descripcion']]

# %%
df_limpio.head()
# Out:
#   Tipo de Propiedad  Ambientes  Superficie Cubierta  Superficie Total  \
# 0                PH        2.0                 40.0              55.0
# 1         apartment        3.0                  NaN               NaN
# 2         apartment        2.0                 55.0              55.0
# 3                PH        3.0                  NaN               NaN
# 4         apartment        2.0                 35.0              35.0
#
#         Pais                     Provincia      Localidad     Barrio  \
# 0  Argentina               Capital Federal      Mataderos  Mataderos
# 1  Argentina        Bs.As. G.B.A. Zona Sur       La Plata   La Plata
# 2  Argentina               Capital Federal      Mataderos  Mataderos
# 3  Argentina               Capital Federal        Liniers    Liniers
# 4  Argentina  Buenos Aires Costa Atlántica  Mar del Plata     Centro
#
#                                               Titulo  \
# 0                 2 AMB TIPO CASA SIN EXPENSAS EN PB
# 1  VENTA Depto 2 dorm. a estrenar 7 e/ 36 y 37   ...
# 2           2 AMB 3ER PISO CON ASCENSOR APTO CREDITO
# 3                       PH 3 amb. cfte. reciclado
# 4  DEPTO 2 AMB AL CONTRAFRENTE ZONA CENTRO/PLAZA ...
#
#                                          Descripcion
# 0  2 AMBIENTES TIPO CASA PLANTA BAJA POR PASILLO,...
# 1  Venta de departamento en décimo piso al frente...
# 2  2 AMBIENTES 3ER PISO LATERAL LIVING COMEDOR AM...
# 3  PH 3 ambientes con patio. Hay 3 deptos en lote...
# 4  DEPARTAMENTO CON FANTÁSTICA ILUMINACIÓN NATURA...

# %%
df_precio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 121220 entries, 0 to 121219
# Data columns (total 11 columns):
# price                         100810 non-null float64
# currency                      100809 non-null object
# price_aprox_local_currency    100810 non-null float64
# price_aprox_usd               100810 non-null float64
# surface_total_in_m2           81892 non-null float64
# surface_covered_in_m2         101313 non-null float64
# price_usd_per_m2              68617 non-null float64
# price_per_m2                  87658 non-null float64
# description                   121218 non-null object
# title                         121220 non-null object
# precio_en_titulo              2434 non-null float64
# dtypes: float64(8), object(3)
# memory usage: 11.1+ MB

# %%
df_limpio['Precio Metro Cuadrado'] = df_precio.price_usd_per_m2               
df_limpio['Precio'] = df_precio.price_aprox_usd

# %%
df_limpio=df_limpio[['Precio Metro Cuadrado','Precio','Tipo de Propiedad','Ambientes','Superficie Cubierta','Superficie Total','Pais','Provincia','Localidad','Barrio','Titulo','Descripcion']]

# %%
df_limpio.head()
# Out:
#    Precio Metro Cuadrado    Precio Tipo de Propiedad  Ambientes  \
# 0            1127.272727   62000.0                PH        2.0
# 1                    NaN  150000.0         apartment        3.0
# 2            1309.090909   72000.0         apartment        2.0
# 3                    NaN   95000.0                PH        3.0
# 4            1828.571429   64000.0         apartment        2.0
#
#    Superficie Cubierta  Superficie Total       Pais  \
# 0                 40.0              55.0  Argentina
# 1                  NaN               NaN  Argentina
# 2                 55.0              55.0  Argentina
# 3                  NaN               NaN  Argentina
# 4                 35.0              35.0  Argentina
#
#                       Provincia      Localidad     Barrio  \
# 0               Capital Federal      Mataderos  Mataderos
# 1        Bs.As. G.B.A. Zona Sur       La Plata   La Plata
# 2               Capital Federal      Mataderos  Mataderos
# 3               Capital Federal        Liniers    Liniers
# 4  Buenos Aires Costa Atlántica  Mar del Plata     Centro
#
#                                               Titulo  \
# 0                 2 AMB TIPO CASA SIN EXPENSAS EN PB
# 1  VENTA Depto 2 dorm. a estrenar 7 e/ 36 y 37   ...
# 2           2 AMB 3ER PISO CON ASCENSOR APTO CREDITO
# 3                       PH 3 amb. cfte. reciclado
# 4  DEPTO 2 AMB AL CONTRAFRENTE ZONA CENTRO/PLAZA ...
#
#                                          Descripcion
# 0  2 AMBIENTES TIPO CASA PLANTA BAJA POR PASILLO,...
# 1  Venta de departamento en décimo piso al frente...
# 2  2 AMBIENTES 3ER PISO LATERAL LIVING COMEDOR AM...
# 3  PH 3 ambientes con patio. Hay 3 deptos en lote...
# 4  DEPARTAMENTO CON FANTÁSTICA ILUMINACIÓN NATURA...

# %% [markdown]
# # Modelado

# %%
df_limpio.iloc[205]
# Out:
# Precio Metro Cuadrado                                                  NaN
# Precio                                                              180000
# Tipo de Propiedad                                                    house
# Ambientes                                                                4
# Superficie Cubierta                                                      0
# Superficie Total                                                         0
# Pais                                                             Argentina
# Provincia                                         Bs.As. G.B.A. Zona Oeste
# Localidad                                                            Morón
# Barrio                                                            Castelar
# Titulo                      Único Chalet en La Mejor Ubicación de Castelar
# Descripcion              Sobre Calle Machado. Chalet totalmente habitab...
# Name: 205, dtype: object

# %%
def recalcular_precio_metro_cuadrado(x):
    try:
        if np.isnan(np.array(x['Precio Metro Cuadrado'])):
            if not(np.isnan(np.array(x['Superficie Total'])) or np.isnan(np.array(x['Precio']))):
                return x['Precio']/x['Superficie Total']
    except:
        return np.nan
df_limpio['Precio Metro Cuadrado'].fillna(df_limpio.apply(recalcular_precio_metro_cuadrado,1),inplace=True)

# %%
df_limpio.isnull().sum()
# Out:
# Precio Metro Cuadrado    28295
# Precio                   20410
# Tipo de Propiedad            0
# Ambientes                11782
# Superficie Cubierta      12369
# Superficie Total         12369
# Pais                         0
# Provincia                    0
# Localidad                    0
# Barrio                       0
# Titulo                       0
# Descripcion                  2
# dtype: int64

# %%
df_definitivo=df_limpio.drop(columns=['Descripcion','Titulo']).dropna()

# %%
df_definitivo.corr()
# Out:
#                        Precio Metro Cuadrado    Precio  Ambientes  \
# Precio Metro Cuadrado               1.000000  0.093867  -0.017936
# Precio                              0.093867  1.000000   0.260459
# Ambientes                          -0.017936  0.260459   1.000000
# Superficie Cubierta                -0.009168  0.390864   0.056676
# Superficie Total                   -0.012272  0.272627   0.067422
#
#                        Superficie Cubierta  Superficie Total
# Precio Metro Cuadrado            -0.009168         -0.012272
# Precio                            0.390864          0.272627
# Ambientes                         0.056676          0.067422
# Superficie Cubierta               1.000000          0.623999
# Superficie Total                  0.623999          1.000000

# %%
df_dummies =pd.get_dummies(df_definitivo,columns=['Localidad','Tipo de Propiedad'], drop_first=True)

# %%
df_dummies.corr()
# Out:
#                                      Precio Metro Cuadrado    Precio  \
# Precio Metro Cuadrado                             1.000000  0.093867
# Precio                                            0.093867  1.000000
# Ambientes                                        -0.017936  0.260459
# Superficie Cubierta                              -0.009168  0.390864
# Superficie Total                                 -0.012272  0.272627
# Localidad_Abasto                                 -0.001333 -0.008774
# Localidad_Achiras                                -0.000294 -0.001400
# Localidad_Agronomía                              -0.000363 -0.004346
# Localidad_Agua Blanca                            -0.000480 -0.001141
# Localidad_Agua de Oro                            -0.000730 -0.001460
# Localidad_Aguas Verdes                           -0.001325 -0.003527
# Localidad_Aldea Brasilera                        -0.000566 -0.001101
# Localidad_Alejandro Roca                          0.004980  0.010060
# Localidad_Almafuerte                             -0.000522 -0.001782
# Localidad_Almagro                                 0.000423 -0.022082
# Localidad_Almirante Brown                        -0.008346 -0.002133
# Localidad_Alta Gracia                            -0.000122  0.005035
# Localidad_Alvear                                 -0.000455 -0.001662
# Localidad_Anisacate                              -0.001133 -0.002549
# Localidad_Apóstoles                              -0.000477  0.000473
# Localidad_Arequito                               -0.000291 -0.000304
# Localidad_Arroyo Ceibal                           0.000420 -0.001502
# Localidad_Arroyo Seco                            -0.000565 -0.001400
# Localidad_Ascochinga                             -0.000791 -0.000641
# Localidad_Avellaneda                              0.000657 -0.028635
# Localidad_Azara                                  -0.000613 -0.001641
# Localidad_Azul                                   -0.001457  0.003288
# Localidad_Bahía Blanca                           -0.006512 -0.021862
# Localidad_Balcarce                               -0.002818 -0.003851
# Localidad_Balvanera                              -0.004095 -0.025084
# ...                                                    ...       ...
# Localidad_Villa Llao Llao                         0.000131  0.010558
# Localidad_Villa Los Aromos                       -0.000578 -0.001980
# Localidad_Villa Lugano                            0.001961 -0.012696
# Localidad_Villa Luro                             -0.001264 -0.014925
# Localidad_Villa María                            -0.000840 -0.002551
# Localidad_Villa Mercedes                         -0.000602 -0.002135
# Localidad_Villa Nueva                             0.000837  0.012551
# Localidad_Villa Ortuzar                          -0.000093 -0.004055
# Localidad_Villa Paranacito                       -0.000306 -0.000752
# Localidad_Villa Parque Santa Ana                 -0.000650  0.000222
# Localidad_Villa Parque Siquiman                   0.000048 -0.000752
# Localidad_Villa Pueyrredón                       -0.001519 -0.007744
# Localidad_Villa Real                             -0.001495 -0.004028
# Localidad_Villa Riachuelo                        -0.000046 -0.001794
# Localidad_Villa Rumipal                          -0.001093 -0.001946
# Localidad_Villa Santa Cruz del Lago              -0.000133  0.000260
# Localidad_Villa Santa Rita                        0.040281 -0.004434
# Localidad_Villa Soldati                          -0.001455 -0.005229
# Localidad_Villa Urquiza                           0.000829 -0.024400
# Localidad_Villa de Las Rosas                     -0.000738  0.002724
# Localidad_Villa de Soto                          -0.000648 -0.002085
# Localidad_Villa del Dique                        -0.000964  0.000554
# Localidad_Villa del Parque                        0.004330 -0.012907
# Localidad_Villa del Totoral                      -0.001028 -0.002656
# Localidad_Wenceslao Escalante                    -0.000542 -0.001961
# Localidad_Yerba Buena                            -0.001325  0.002824
# Localidad_Zárate                                 -0.000645  0.004983
# Tipo de Propiedad_apartment                       0.020391 -0.169955
# Tipo de Propiedad_house                          -0.022902  0.198212
# Tipo de Propiedad_store                           0.020422  0.049980
#
#                                      Ambientes  Superficie Cubierta  \
# Precio Metro Cuadrado                -0.017936            -0.009168
# Precio                                0.260459             0.390864
# Ambientes                             1.000000             0.056676
# Superficie Cubierta                   0.056676             1.000000
# Superficie Total                      0.067422             0.623999
# Localidad_Abasto                     -0.010587            -0.001843
# Localidad_Achiras                    -0.003853            -0.000197
# Localidad_Agronomía                  -0.005731            -0.000922
# Localidad_Agua Blanca                -0.000589             0.000254
# Localidad_Agua de Oro                 0.003783             0.000188
# Localidad_Aguas Verdes                0.001889            -0.000063
# Localidad_Aldea Brasilera             0.001043            -0.000023
# Localidad_Alejandro Roca             -0.003853            -0.000329
# Localidad_Almafuerte                 -0.003853             0.000036
# Localidad_Almagro                    -0.039733            -0.005951
# Localidad_Almirante Brown             0.062239             0.002967
# Localidad_Alta Gracia                 0.003673             0.000864
# Localidad_Alvear                      0.001043            -0.000232
# Localidad_Anisacate                   0.004554             0.000580
# Localidad_Apóstoles                  -0.003853             0.000150
# Localidad_Arequito                    0.001043             0.000067
# Localidad_Arroyo Ceibal               0.007571            -0.000370
# Localidad_Arroyo Seco                -0.000589            -0.000128
# Localidad_Ascochinga                 -0.001963             0.000909
# Localidad_Avellaneda                 -0.019377            -0.002842
# Localidad_Azara                      -0.000589             0.000775
# Localidad_Azul                        0.006477             0.000468
# Localidad_Bahía Blanca                0.028613             0.000756
# Localidad_Balcarce                   -0.003584             0.001513
# Localidad_Balvanera                  -0.023967            -0.004137
# ...                                        ...                  ...
# Localidad_Villa Llao Llao             0.009203             0.000948
# Localidad_Villa Los Aromos            0.000321            -0.000080
# Localidad_Villa Lugano                0.003707            -0.000673
# Localidad_Villa Luro                 -0.027436            -0.003786
# Localidad_Villa María                 0.005982             0.000048
# Localidad_Villa Mercedes              0.001043            -0.000128
# Localidad_Villa Nueva                 0.002675            -0.000023
# Localidad_Villa Ortuzar              -0.008454            -0.001501
# Localidad_Villa Paranacito            0.001043            -0.000023
# Localidad_Villa Parque Santa Ana      0.004633             0.000663
# Localidad_Villa Parque Siquiman      -0.002221            -0.000315
# Localidad_Villa Pueyrredón           -0.010006            -0.002041
# Localidad_Villa Real                 -0.000814            -0.000725
# Localidad_Villa Riachuelo             0.000872            -0.000305
# Localidad_Villa Rumipal              -0.000110             0.000465
# Localidad_Villa Santa Cruz del Lago   0.001219            -0.000157
# Localidad_Villa Santa Rita           -0.005441            -0.001629
# Localidad_Villa Soldati               0.000592            -0.000217
# Localidad_Villa Urquiza              -0.045985            -0.007988
# Localidad_Villa de Las Rosas          0.011230             0.002143
# Localidad_Villa de Soto              -0.000833             0.000040
# Localidad_Villa del Dique             0.005879             0.000464
# Localidad_Villa del Parque           -0.016093            -0.003783
# Localidad_Villa del Totoral          -0.000078            -0.000031
# Localidad_Wenceslao Escalante         0.002675            -0.000023
# Localidad_Yerba Buena                 0.004556             0.000568
# Localidad_Zárate                      0.004085             0.028711
# Tipo de Propiedad_apartment          -0.404762            -0.061183
# Tipo de Propiedad_house               0.423620             0.064409
# Tipo de Propiedad_store              -0.019145             0.023969
#
#                                      Superficie Total  Localidad_Abasto  \
# Precio Metro Cuadrado                       -0.012272         -0.001333
# Precio                                       0.272627         -0.008774
# Ambientes                                    0.067422         -0.010587
# Superficie Cubierta                          0.623999         -0.001843
# Superficie Total                             1.000000         -0.002384
# Localidad_Abasto                            -0.002384          1.000000
# Localidad_Achiras                           -0.000275         -0.000112
# Localidad_Agronomía                         -0.001352         -0.000681
# Localidad_Agua Blanca                        0.000003         -0.000112
# Localidad_Agua de Oro                        0.001244         -0.000158
# Localidad_Aguas Verdes                       0.001269         -0.000274
# Localidad_Aldea Brasilera                    0.000644         -0.000112
# Localidad_Alejandro Roca                    -0.000314         -0.000112
# Localidad_Almafuerte                        -0.000132         -0.000112
# Localidad_Almagro                           -0.007521         -0.003449
# Localidad_Almirante Brown                   -0.000218         -0.003649
# Localidad_Alta Gracia                        0.001427         -0.000336
# Localidad_Alvear                            -0.000211         -0.000112
# Localidad_Anisacate                         -0.000019         -0.000274
# Localidad_Apóstoles                          0.000537         -0.000112
# Localidad_Arequito                          -0.000113         -0.000112
# Localidad_Arroyo Ceibal                     -0.000382         -0.000112
# Localidad_Arroyo Seco                        0.000383         -0.000112
# Localidad_Ascochinga                         0.000294         -0.000194
# Localidad_Avellaneda                        -0.004874         -0.002675
# Localidad_Azara                              0.002248         -0.000112
# Localidad_Azul                               0.001313         -0.000403
# Localidad_Bahía Blanca                       0.001006         -0.002073
# Localidad_Balcarce                           0.001703         -0.000681
# Localidad_Balvanera                         -0.005937         -0.002708
# ...                                               ...               ...
# Localidad_Villa Llao Llao                    0.000430         -0.000112
# Localidad_Villa Los Aromos                  -0.000267         -0.000158
# Localidad_Villa Lugano                      -0.001807         -0.001412
# Localidad_Villa Luro                        -0.004774         -0.002079
# Localidad_Villa María                       -0.000310         -0.000250
# Localidad_Villa Mercedes                     0.000110         -0.000112
# Localidad_Villa Nueva                        0.000086         -0.000112
# Localidad_Villa Ortuzar                     -0.002011         -0.000943
# Localidad_Villa Paranacito                  -0.000168         -0.000112
# Localidad_Villa Parque Santa Ana             0.000142         -0.000194
# Localidad_Villa Parque Siquiman             -0.000303         -0.000112
# Localidad_Villa Pueyrredón                  -0.002785         -0.001443
# Localidad_Villa Real                        -0.000950         -0.000671
# Localidad_Villa Riachuelo                   -0.000365         -0.000250
# Localidad_Villa Rumipal                      0.000552         -0.000274
# Localidad_Villa Santa Cruz del Lago          0.001449         -0.000316
# Localidad_Villa Santa Rita                  -0.001765         -0.000822
# Localidad_Villa Soldati                     -0.000566         -0.000403
# Localidad_Villa Urquiza                     -0.009652         -0.004004
# Localidad_Villa de Las Rosas                 0.001054         -0.000194
# Localidad_Villa de Soto                     -0.000193         -0.000158
# Localidad_Villa del Dique                   -0.000106         -0.000354
# Localidad_Villa del Parque                  -0.004984         -0.002342
# Localidad_Villa del Totoral                  0.001604         -0.000194
# Localidad_Wenceslao Escalante               -0.000168         -0.000112
# Localidad_Yerba Buena                        0.000941         -0.000388
# Localidad_Zárate                             0.168391         -0.000388
# Tipo de Propiedad_apartment                 -0.082758          0.013714
# Tipo de Propiedad_house                      0.090291         -0.020723
# Tipo de Propiedad_store                      0.013181          0.002055
#
#                                      Localidad_Achiras  Localidad_Agronomía  \
# Precio Metro Cuadrado                        -0.000294            -0.000363
# Precio                                       -0.001400            -0.004346
# Ambientes                                    -0.003853            -0.005731
# Superficie Cubierta                          -0.000197            -0.000922
# Superficie Total                             -0.000275            -0.001352
# Localidad_Abasto                             -0.000112            -0.000681
# Localidad_Achiras                             1.000000            -0.000071
# Localidad_Agronomía                          -0.000071             1.000000
# Localidad_Agua Blanca                        -0.000012            -0.000071
# Localidad_Agua de Oro                        -0.000017            -0.000101
# Localidad_Aguas Verdes                       -0.000029            -0.000175
# Localidad_Aldea Brasilera                    -0.000012            -0.000071
# Localidad_Alejandro Roca                     -0.000012            -0.000071
# Localidad_Almafuerte                         -0.000012            -0.000071
# Localidad_Almagro                            -0.000361            -0.002198
# Localidad_Almirante Brown                    -0.000382            -0.002326
# Localidad_Alta Gracia                        -0.000035            -0.000214
# Localidad_Alvear                             -0.000012            -0.000071
# Localidad_Anisacate                          -0.000029            -0.000175
# Localidad_Apóstoles                          -0.000012            -0.000071
# Localidad_Arequito                           -0.000012            -0.000071
# Localidad_Arroyo Ceibal                      -0.000012            -0.000071
# Localidad_Arroyo Seco                        -0.000012            -0.000071
# Localidad_Ascochinga                         -0.000020            -0.000124
# Localidad_Avellaneda                         -0.000280            -0.001705
# Localidad_Azara                              -0.000012            -0.000071
# Localidad_Azul                               -0.000042            -0.000257
# Localidad_Bahía Blanca                       -0.000217            -0.001321
# Localidad_Balcarce                           -0.000071            -0.000434
# Localidad_Balvanera                          -0.000284            -0.001726
# ...                                                ...                  ...
# Localidad_Villa Llao Llao                    -0.000012            -0.000071
# Localidad_Villa Los Aromos                   -0.000017            -0.000101
# Localidad_Villa Lugano                       -0.000148            -0.000900
# Localidad_Villa Luro                         -0.000218            -0.001325
# Localidad_Villa María                        -0.000026            -0.000159
# Localidad_Villa Mercedes                     -0.000012            -0.000071
# Localidad_Villa Nueva                        -0.000012            -0.000071
# Localidad_Villa Ortuzar                      -0.000099            -0.000601
# Localidad_Villa Paranacito                   -0.000012            -0.000071
# Localidad_Villa Parque Santa Ana             -0.000020            -0.000124
# Localidad_Villa Parque Siquiman              -0.000012            -0.000071
# Localidad_Villa Pueyrredón                   -0.000151            -0.000920
# Localidad_Villa Real                         -0.000070            -0.000428
# Localidad_Villa Riachuelo                    -0.000026            -0.000159
# Localidad_Villa Rumipal                      -0.000029            -0.000175
# Localidad_Villa Santa Cruz del Lago          -0.000033            -0.000202
# Localidad_Villa Santa Rita                   -0.000086            -0.000524
# Localidad_Villa Soldati                      -0.000042            -0.000257
# Localidad_Villa Urquiza                      -0.000419            -0.002552
# Localidad_Villa de Las Rosas                 -0.000020            -0.000124
# Localidad_Villa de Soto                      -0.000017            -0.000101
# Localidad_Villa del Dique                    -0.000037            -0.000226
# Localidad_Villa del Parque                   -0.000245            -0.001493
# Localidad_Villa del Totoral                  -0.000020            -0.000124
# Localidad_Wenceslao Escalante                -0.000012            -0.000071
# Localidad_Yerba Buena                        -0.000041            -0.000247
# Localidad_Zárate                             -0.000041            -0.000247
# Tipo de Propiedad_apartment                  -0.004267             0.005181
# Tipo de Propiedad_house                       0.004862            -0.012277
# Tipo de Propiedad_store                      -0.000268             0.005602
#
#                                      Localidad_Agua Blanca  \
# Precio Metro Cuadrado                            -0.000480
# Precio                                           -0.001141
# Ambientes                                        -0.000589
# Superficie Cubierta                               0.000254
# Superficie Total                                  0.000003
# Localidad_Abasto                                 -0.000112
# Localidad_Achiras                                -0.000012
# Localidad_Agronomía                              -0.000071
# Localidad_Agua Blanca                             1.000000
# Localidad_Agua de Oro                            -0.000017
# Localidad_Aguas Verdes                           -0.000029
# Localidad_Aldea Brasilera                        -0.000012
# Localidad_Alejandro Roca                         -0.000012
# Localidad_Almafuerte                             -0.000012
# Localidad_Almagro                                -0.000361
# Localidad_Almirante Brown                        -0.000382
# Localidad_Alta Gracia                            -0.000035
# Localidad_Alvear                                 -0.000012
# Localidad_Anisacate                              -0.000029
# Localidad_Apóstoles                              -0.000012
# Localidad_Arequito                               -0.000012
# Localidad_Arroyo Ceibal                          -0.000012
# Localidad_Arroyo Seco                            -0.000012
# Localidad_Ascochinga                             -0.000020
# Localidad_Avellaneda                             -0.000280
# Localidad_Azara                                  -0.000012
# Localidad_Azul                                   -0.000042
# Localidad_Bahía Blanca                           -0.000217
# Localidad_Balcarce                               -0.000071
# Localidad_Balvanera                              -0.000284
# ...                                                    ...
# Localidad_Villa Llao Llao                        -0.000012
# Localidad_Villa Los Aromos                       -0.000017
# Localidad_Villa Lugano                           -0.000148
# Localidad_Villa Luro                             -0.000218
# Localidad_Villa María                            -0.000026
# Localidad_Villa Mercedes                         -0.000012
# Localidad_Villa Nueva                            -0.000012
# Localidad_Villa Ortuzar                          -0.000099
# Localidad_Villa Paranacito                       -0.000012
# Localidad_Villa Parque Santa Ana                 -0.000020
# Localidad_Villa Parque Siquiman                  -0.000012
# Localidad_Villa Pueyrredón                       -0.000151
# Localidad_Villa Real                             -0.000070
# Localidad_Villa Riachuelo                        -0.000026
# Localidad_Villa Rumipal                          -0.000029
# Localidad_Villa Santa Cruz del Lago              -0.000033
# Localidad_Villa Santa Rita                       -0.000086
# Localidad_Villa Soldati                          -0.000042
# Localidad_Villa Urquiza                          -0.000419
# Localidad_Villa de Las Rosas                     -0.000020
# Localidad_Villa de Soto                          -0.000017
# Localidad_Villa del Dique                        -0.000037
# Localidad_Villa del Parque                       -0.000245
# Localidad_Villa del Totoral                      -0.000020
# Localidad_Wenceslao Escalante                    -0.000012
# Localidad_Yerba Buena                            -0.000041
# Localidad_Zárate                                 -0.000041
# Tipo de Propiedad_apartment                      -0.004267
# Tipo de Propiedad_house                           0.004862
# Tipo de Propiedad_store                          -0.000268
#
#                                      Localidad_Agua de Oro  ...  \
# Precio Metro Cuadrado                            -0.000730  ...
# Precio                                           -0.001460  ...
# Ambientes                                         0.003783  ...
# Superficie Cubierta                               0.000188  ...
# Superficie Total                                  0.001244  ...
# Localidad_Abasto                                 -0.000158  ...
# Localidad_Achiras                                -0.000017  ...
# Localidad_Agronomía                              -0.000101  ...
# Localidad_Agua Blanca                            -0.000017  ...
# Localidad_Agua de Oro                             1.000000  ...
# Localidad_Aguas Verdes                           -0.000041  ...
# Localidad_Aldea Brasilera                        -0.000017  ...
# Localidad_Alejandro Roca                         -0.000017  ...
# Localidad_Almafuerte                             -0.000017  ...
# Localidad_Almagro                                -0.000511  ...
# Localidad_Almirante Brown                        -0.000541  ...
# Localidad_Alta Gracia                            -0.000050  ...
# Localidad_Alvear                                 -0.000017  ...
# Localidad_Anisacate                              -0.000041  ...
# Localidad_Apóstoles                              -0.000017  ...
# Localidad_Arequito                               -0.000017  ...
# Localidad_Arroyo Ceibal                          -0.000017  ...
# Localidad_Arroyo Seco                            -0.000017  ...
# Localidad_Ascochinga                             -0.000029  ...
# Localidad_Avellaneda                             -0.000396  ...
# Localidad_Azara                                  -0.000017  ...
# Localidad_Azul                                   -0.000060  ...
# Localidad_Bahía Blanca                           -0.000307  ...
# Localidad_Balcarce                               -0.000101  ...
# Localidad_Balvanera                              -0.000401  ...
# ...                                                    ...  ...
# Localidad_Villa Llao Llao                        -0.000017  ...
# Localidad_Villa Los Aromos                       -0.000023  ...
# Localidad_Villa Lugano                           -0.000209  ...
# Localidad_Villa Luro                             -0.000308  ...
# Localidad_Villa María                            -0.000037  ...
# Localidad_Villa Mercedes                         -0.000017  ...
# Localidad_Villa Nueva                            -0.000017  ...
# Localidad_Villa Ortuzar                          -0.000140  ...
# Localidad_Villa Paranacito                       -0.000017  ...
# Localidad_Villa Parque Santa Ana                 -0.000029  ...
# Localidad_Villa Parque Siquiman                  -0.000017  ...
# Localidad_Villa Pueyrredón                       -0.000214  ...
# Localidad_Villa Real                             -0.000099  ...
# Localidad_Villa Riachuelo                        -0.000037  ...
# Localidad_Villa Rumipal                          -0.000041  ...
# Localidad_Villa Santa Cruz del Lago              -0.000047  ...
# Localidad_Villa Santa Rita                       -0.000122  ...
# Localidad_Villa Soldati                          -0.000060  ...
# Localidad_Villa Urquiza                          -0.000593  ...
# Localidad_Villa de Las Rosas                     -0.000029  ...
# Localidad_Villa de Soto                          -0.000023  ...
# Localidad_Villa del Dique                        -0.000052  ...
# Localidad_Villa del Parque                       -0.000347  ...
# Localidad_Villa del Totoral                      -0.000029  ...
# Localidad_Wenceslao Escalante                    -0.000017  ...
# Localidad_Yerba Buena                            -0.000057  ...
# Localidad_Zárate                                 -0.000057  ...
# Tipo de Propiedad_apartment                      -0.006034  ...
# Tipo de Propiedad_house                           0.006875  ...
# Tipo de Propiedad_store                          -0.000379  ...
#
#                                      Localidad_Villa de Soto  \
# Precio Metro Cuadrado                              -0.000648
# Precio                                             -0.002085
# Ambientes                                          -0.000833
# Superficie Cubierta                                 0.000040
# Superficie Total                                   -0.000193
# Localidad_Abasto                                   -0.000158
# Localidad_Achiras                                  -0.000017
# Localidad_Agronomía                                -0.000101
# Localidad_Agua Blanca                              -0.000017
# Localidad_Agua de Oro                              -0.000023
# Localidad_Aguas Verdes                             -0.000041
# Localidad_Aldea Brasilera                          -0.000017
# Localidad_Alejandro Roca                           -0.000017
# Localidad_Almafuerte                               -0.000017
# Localidad_Almagro                                  -0.000511
# Localidad_Almirante Brown                          -0.000541
# Localidad_Alta Gracia                              -0.000050
# Localidad_Alvear                                   -0.000017
# Localidad_Anisacate                                -0.000041
# Localidad_Apóstoles                                -0.000017
# Localidad_Arequito                                 -0.000017
# Localidad_Arroyo Ceibal                            -0.000017
# Localidad_Arroyo Seco                              -0.000017
# Localidad_Ascochinga                               -0.000029
# Localidad_Avellaneda                               -0.000396
# Localidad_Azara                                    -0.000017
# Localidad_Azul                                     -0.000060
# Localidad_Bahía Blanca                             -0.000307
# Localidad_Balcarce                                 -0.000101
# Localidad_Balvanera                                -0.000401
# ...                                                      ...
# Localidad_Villa Llao Llao                          -0.000017
# Localidad_Villa Los Aromos                         -0.000023
# Localidad_Villa Lugano                             -0.000209
# Localidad_Villa Luro                               -0.000308
# Localidad_Villa María                              -0.000037
# Localidad_Villa Mercedes                           -0.000017
# Localidad_Villa Nueva                              -0.000017
# Localidad_Villa Ortuzar                            -0.000140
# Localidad_Villa Paranacito                         -0.000017
# Localidad_Villa Parque Santa Ana                   -0.000029
# Localidad_Villa Parque Siquiman                    -0.000017
# Localidad_Villa Pueyrredón                         -0.000214
# Localidad_Villa Real                               -0.000099
# Localidad_Villa Riachuelo                          -0.000037
# Localidad_Villa Rumipal                            -0.000041
# Localidad_Villa Santa Cruz del Lago                -0.000047
# Localidad_Villa Santa Rita                         -0.000122
# Localidad_Villa Soldati                            -0.000060
# Localidad_Villa Urquiza                            -0.000593
# Localidad_Villa de Las Rosas                       -0.000029
# Localidad_Villa de Soto                             1.000000
# Localidad_Villa del Dique                          -0.000052
# Localidad_Villa del Parque                         -0.000347
# Localidad_Villa del Totoral                        -0.000029
# Localidad_Wenceslao Escalante                      -0.000017
# Localidad_Yerba Buena                              -0.000057
# Localidad_Zárate                                   -0.000057
# Tipo de Propiedad_apartment                        -0.006034
# Tipo de Propiedad_house                             0.006875
# Tipo de Propiedad_store                            -0.000379
#
#                                      Localidad_Villa del Dique  \
# Precio Metro Cuadrado                                -0.000964
# Precio                                                0.000554
# Ambientes                                             0.005879
# Superficie Cubierta                                   0.000464
# Superficie Total                                     -0.000106
# Localidad_Abasto                                     -0.000354
# Localidad_Achiras                                    -0.000037
# Localidad_Agronomía                                  -0.000226
# Localidad_Agua Blanca                                -0.000037
# Localidad_Agua de Oro                                -0.000052
# Localidad_Aguas Verdes                               -0.000091
# Localidad_Aldea Brasilera                            -0.000037
# Localidad_Alejandro Roca                             -0.000037
# Localidad_Almafuerte                                 -0.000037
# Localidad_Almagro                                    -0.001143
# Localidad_Almirante Brown                            -0.001209
# Localidad_Alta Gracia                                -0.000111
# Localidad_Alvear                                     -0.000037
# Localidad_Anisacate                                  -0.000091
# Localidad_Apóstoles                                  -0.000037
# Localidad_Arequito                                   -0.000037
# Localidad_Arroyo Ceibal                              -0.000037
# Localidad_Arroyo Seco                                -0.000037
# Localidad_Ascochinga                                 -0.000064
# Localidad_Avellaneda                                 -0.000886
# Localidad_Azara                                      -0.000037
# Localidad_Azul                                       -0.000134
# Localidad_Bahía Blanca                               -0.000687
# Localidad_Balcarce                                   -0.000226
# Localidad_Balvanera                                  -0.000897
# ...                                                        ...
# Localidad_Villa Llao Llao                            -0.000037
# Localidad_Villa Los Aromos                           -0.000052
# Localidad_Villa Lugano                               -0.000468
# Localidad_Villa Luro                                 -0.000689
# Localidad_Villa María                                -0.000083
# Localidad_Villa Mercedes                             -0.000037
# Localidad_Villa Nueva                                -0.000037
# Localidad_Villa Ortuzar                              -0.000312
# Localidad_Villa Paranacito                           -0.000037
# Localidad_Villa Parque Santa Ana                     -0.000064
# Localidad_Villa Parque Siquiman                      -0.000037
# Localidad_Villa Pueyrredón                           -0.000478
# Localidad_Villa Real                                 -0.000222
# Localidad_Villa Riachuelo                            -0.000083
# Localidad_Villa Rumipal                              -0.000091
# Localidad_Villa Santa Cruz del Lago                  -0.000105
# Localidad_Villa Santa Rita                           -0.000272
# Localidad_Villa Soldati                              -0.000134
# Localidad_Villa Urquiza                              -0.001327
# Localidad_Villa de Las Rosas                         -0.000064
# Localidad_Villa de Soto                              -0.000052
# Localidad_Villa del Dique                             1.000000
# Localidad_Villa del Parque                           -0.000776
# Localidad_Villa del Totoral                          -0.000064
# Localidad_Wenceslao Escalante                        -0.000037
# Localidad_Yerba Buena                                -0.000128
# Localidad_Zárate                                     -0.000128
# Tipo de Propiedad_apartment                          -0.013493
# Tipo de Propiedad_house                               0.015375
# Tipo de Propiedad_store                              -0.000848
#
#                                      Localidad_Villa del Parque  \
# Precio Metro Cuadrado                                  0.004330
# Precio                                                -0.012907
# Ambientes                                             -0.016093
# Superficie Cubierta                                   -0.003783
# Superficie Total                                      -0.004984
# Localidad_Abasto                                      -0.002342
# Localidad_Achiras                                     -0.000245
# Localidad_Agronomía                                   -0.001493
# Localidad_Agua Blanca                                 -0.000245
# Localidad_Agua de Oro                                 -0.000347
# Localidad_Aguas Verdes                                -0.000601
# Localidad_Aldea Brasilera                             -0.000245
# Localidad_Alejandro Roca                              -0.000245
# Localidad_Almafuerte                                  -0.000245
# Localidad_Almagro                                     -0.007565
# Localidad_Almirante Brown                             -0.008004
# Localidad_Alta Gracia                                 -0.000736
# Localidad_Alvear                                      -0.000245
# Localidad_Anisacate                                   -0.000601
# Localidad_Apóstoles                                   -0.000245
# Localidad_Arequito                                    -0.000245
# Localidad_Arroyo Ceibal                               -0.000245
# Localidad_Arroyo Seco                                 -0.000245
# Localidad_Ascochinga                                  -0.000425
# Localidad_Avellaneda                                  -0.005867
# Localidad_Azara                                       -0.000245
# Localidad_Azul                                        -0.000885
# Localidad_Bahía Blanca                                -0.004547
# Localidad_Balcarce                                    -0.001493
# Localidad_Balvanera                                   -0.005940
# ...                                                         ...
# Localidad_Villa Llao Llao                             -0.000245
# Localidad_Villa Los Aromos                            -0.000347
# Localidad_Villa Lugano                                -0.003097
# Localidad_Villa Luro                                  -0.004560
# Localidad_Villa María                                 -0.000549
# Localidad_Villa Mercedes                              -0.000245
# Localidad_Villa Nueva                                 -0.000245
# Localidad_Villa Ortuzar                               -0.002068
# Localidad_Villa Paranacito                            -0.000245
# Localidad_Villa Parque Santa Ana                      -0.000425
# Localidad_Villa Parque Siquiman                       -0.000245
# Localidad_Villa Pueyrredón                            -0.003164
# Localidad_Villa Real                                  -0.001473
# Localidad_Villa Riachuelo                             -0.000549
# Localidad_Villa Rumipal                               -0.000601
# Localidad_Villa Santa Cruz del Lago                   -0.000694
# Localidad_Villa Santa Rita                            -0.001804
# Localidad_Villa Soldati                               -0.000885
# Localidad_Villa Urquiza                               -0.008782
# Localidad_Villa de Las Rosas                          -0.000425
# Localidad_Villa de Soto                               -0.000347
# Localidad_Villa del Dique                             -0.000776
# Localidad_Villa del Parque                             1.000000
# Localidad_Villa del Totoral                           -0.000425
# Localidad_Wenceslao Escalante                         -0.000245
# Localidad_Yerba Buena                                 -0.000850
# Localidad_Zárate                                      -0.000850
# Tipo de Propiedad_apartment                            0.025180
# Tipo de Propiedad_house                               -0.034408
# Tipo de Propiedad_store                                0.000724
#
#                                      Localidad_Villa del Totoral  \
# Precio Metro Cuadrado                                  -0.001028
# Precio                                                 -0.002656
# Ambientes                                              -0.000078
# Superficie Cubierta                                    -0.000031
# Superficie Total                                        0.001604
# Localidad_Abasto                                       -0.000194
# Localidad_Achiras                                      -0.000020
# Localidad_Agronomía                                    -0.000124
# Localidad_Agua Blanca                                  -0.000020
# Localidad_Agua de Oro                                  -0.000029
# Localidad_Aguas Verdes                                 -0.000050
# Localidad_Aldea Brasilera                              -0.000020
# Localidad_Alejandro Roca                               -0.000020
# Localidad_Almafuerte                                   -0.000020
# Localidad_Almagro                                      -0.000626
# Localidad_Almirante Brown                              -0.000662
# Localidad_Alta Gracia                                  -0.000061
# Localidad_Alvear                                       -0.000020
# Localidad_Anisacate                                    -0.000050
# Localidad_Apóstoles                                    -0.000020
# Localidad_Arequito                                     -0.000020
# Localidad_Arroyo Ceibal                                -0.000020
# Localidad_Arroyo Seco                                  -0.000020
# Localidad_Ascochinga                                   -0.000035
# Localidad_Avellaneda                                   -0.000485
# Localidad_Azara                                        -0.000020
# Localidad_Azul                                         -0.000073
# Localidad_Bahía Blanca                                 -0.000376
# Localidad_Balcarce                                     -0.000124
# Localidad_Balvanera                                    -0.000491
# ...                                                          ...
# Localidad_Villa Llao Llao                              -0.000020
# Localidad_Villa Los Aromos                             -0.000029
# Localidad_Villa Lugano                                 -0.000256
# Localidad_Villa Luro                                   -0.000377
# Localidad_Villa María                                  -0.000045
# Localidad_Villa Mercedes                               -0.000020
# Localidad_Villa Nueva                                  -0.000020
# Localidad_Villa Ortuzar                                -0.000171
# Localidad_Villa Paranacito                             -0.000020
# Localidad_Villa Parque Santa Ana                       -0.000035
# Localidad_Villa Parque Siquiman                        -0.000020
# Localidad_Villa Pueyrredón                             -0.000262
# Localidad_Villa Real                                   -0.000122
# Localidad_Villa Riachuelo                              -0.000045
# Localidad_Villa Rumipal                                -0.000050
# Localidad_Villa Santa Cruz del Lago                    -0.000057
# Localidad_Villa Santa Rita                             -0.000149
# Localidad_Villa Soldati                                -0.000073
# Localidad_Villa Urquiza                                -0.000727
# Localidad_Villa de Las Rosas                           -0.000035
# Localidad_Villa de Soto                                -0.000029
# Localidad_Villa del Dique                              -0.000064
# Localidad_Villa del Parque                             -0.000425
# Localidad_Villa del Totoral                             1.000000
# Localidad_Wenceslao Escalante                          -0.000020
# Localidad_Yerba Buena                                  -0.000070
# Localidad_Zárate                                       -0.000070
# Tipo de Propiedad_apartment                            -0.007390
# Tipo de Propiedad_house                                 0.008421
# Tipo de Propiedad_store                                -0.000464
#
#                                      Localidad_Wenceslao Escalante  \
# Precio Metro Cuadrado                                    -0.000542
# Precio                                                   -0.001961
# Ambientes                                                 0.002675
# Superficie Cubierta                                      -0.000023
# Superficie Total                                         -0.000168
# Localidad_Abasto                                         -0.000112
# Localidad_Achiras                                        -0.000012
# Localidad_Agronomía                                      -0.000071
# Localidad_Agua Blanca                                    -0.000012
# Localidad_Agua de Oro                                    -0.000017
# Localidad_Aguas Verdes                                   -0.000029
# Localidad_Aldea Brasilera                                -0.000012
# Localidad_Alejandro Roca                                 -0.000012
# Localidad_Almafuerte                                     -0.000012
# Localidad_Almagro                                        -0.000361
# Localidad_Almirante Brown                                -0.000382
# Localidad_Alta Gracia                                    -0.000035
# Localidad_Alvear                                         -0.000012
# Localidad_Anisacate                                      -0.000029
# Localidad_Apóstoles                                      -0.000012
# Localidad_Arequito                                       -0.000012
# Localidad_Arroyo Ceibal                                  -0.000012
# Localidad_Arroyo Seco                                    -0.000012
# Localidad_Ascochinga                                     -0.000020
# Localidad_Avellaneda                                     -0.000280
# Localidad_Azara                                          -0.000012
# Localidad_Azul                                           -0.000042
# Localidad_Bahía Blanca                                   -0.000217
# Localidad_Balcarce                                       -0.000071
# Localidad_Balvanera                                      -0.000284
# ...                                                            ...
# Localidad_Villa Llao Llao                                -0.000012
# Localidad_Villa Los Aromos                               -0.000017
# Localidad_Villa Lugano                                   -0.000148
# Localidad_Villa Luro                                     -0.000218
# Localidad_Villa María                                    -0.000026
# Localidad_Villa Mercedes                                 -0.000012
# Localidad_Villa Nueva                                    -0.000012
# Localidad_Villa Ortuzar                                  -0.000099
# Localidad_Villa Paranacito                               -0.000012
# Localidad_Villa Parque Santa Ana                         -0.000020
# Localidad_Villa Parque Siquiman                          -0.000012
# Localidad_Villa Pueyrredón                               -0.000151
# Localidad_Villa Real                                     -0.000070
# Localidad_Villa Riachuelo                                -0.000026
# Localidad_Villa Rumipal                                  -0.000029
# Localidad_Villa Santa Cruz del Lago                      -0.000033
# Localidad_Villa Santa Rita                               -0.000086
# Localidad_Villa Soldati                                  -0.000042
# Localidad_Villa Urquiza                                  -0.000419
# Localidad_Villa de Las Rosas                             -0.000020
# Localidad_Villa de Soto                                  -0.000017
# Localidad_Villa del Dique                                -0.000037
# Localidad_Villa del Parque                               -0.000245
# Localidad_Villa del Totoral                              -0.000020
# Localidad_Wenceslao Escalante                             1.000000
# Localidad_Yerba Buena                                    -0.000041
# Localidad_Zárate                                         -0.000041
# Tipo de Propiedad_apartment                              -0.004267
# Tipo de Propiedad_house                                   0.004862
# Tipo de Propiedad_store                                  -0.000268
#
#                                      Localidad_Yerba Buena  Localidad_Zárate  \
# Precio Metro Cuadrado                            -0.001325         -0.000645
# Precio                                            0.002824          0.004983
# Ambientes                                         0.004556          0.004085
# Superficie Cubierta                               0.000568          0.028711
# Superficie Total                                  0.000941          0.168391
# Localidad_Abasto                                 -0.000388         -0.000388
# Localidad_Achiras                                -0.000041         -0.000041
# Localidad_Agronomía                              -0.000247         -0.000247
# Localidad_Agua Blanca                            -0.000041         -0.000041
# ...
# Localidad_Almafuerte                             -0.000041         -0.000041
# Localidad_Almagro                                -0.001252         -0.001252
# Localidad_Almirante Brown                        -0.001325         -0.001325
# Localidad_Alta Gracia                            -0.000122         -0.000122
# Localidad_Alvear                                 -0.000041         -0.000041
# Localidad_Anisacate                              -0.000099         -0.000099
# Localidad_Apóstoles                              -0.000041         -0.000041
# Localidad_Arequito                               -0.000041         -0.000041
# Localidad_Arroyo Ceibal                          -0.000041         -0.000041
# Localidad_Arroyo Seco                            -0.000041         -0.000041
# Localidad_Ascochinga                             -0.000070         -0.000070
# Localidad_Avellaneda                             -0.000971         -0.000971
# Localidad_Azara                                  -0.000041         -0.000041
# Localidad_Azul                                   -0.000146         -0.000146
# Localidad_Bahía Blanca                           -0.000752         -0.000752
# Localidad_Balcarce                               -0.000247         -0.000247
# Localidad_Balvanera                              -0.000983         -0.000983
# ...                                                    ...               ...
# Localidad_Villa Llao Llao                        -0.000041         -0.000041
# Localidad_Villa Los Aromos                       -0.000057         -0.000057
# Localidad_Villa Lugano                           -0.000512         -0.000512
# Localidad_Villa Luro                             -0.000755         -0.000755
# Localidad_Villa María                            -0.000091         -0.000091
# Localidad_Villa Mercedes                         -0.000041         -0.000041
# Localidad_Villa Nueva                            -0.000041         -0.000041
# Localidad_Villa Ortuzar                          -0.000342         -0.000342
# Localidad_Villa Paranacito                       -0.000041         -0.000041
# Localidad_Villa Parque Santa Ana                 -0.000070         -0.000070
# Localidad_Villa Parque Siquiman                  -0.000041         -0.000041
# Localidad_Villa Pueyrredón                       -0.000524         -0.000524
# Localidad_Villa Real                             -0.000244         -0.000244
# Localidad_Villa Riachuelo                        -0.000091         -0.000091
# Localidad_Villa Rumipal                          -0.000099         -0.000099
# Localidad_Villa Santa Cruz del Lago              -0.000115         -0.000115
# Localidad_Villa Santa Rita                       -0.000298         -0.000298
# Localidad_Villa Soldati                          -0.000146         -0.000146
# Localidad_Villa Urquiza                          -0.001453         -0.001453
# Localidad_Villa de Las Rosas                     -0.000070         -0.000070
# Localidad_Villa de Soto                          -0.000057         -0.000057
# Localidad_Villa del Dique                        -0.000128         -0.000128
# Localidad_Villa del Parque                       -0.000850         -0.000850
# Localidad_Villa del Totoral                      -0.000070         -0.000070
# Localidad_Wenceslao Escalante                    -0.000041         -0.000041
# Localidad_Yerba Buena                             1.000000         -0.000141
# Localidad_Zárate                                 -0.000141          1.000000
# Tipo de Propiedad_apartment                      -0.010731         -0.014781
# Tipo de Propiedad_house                           0.012643          0.016842
# Tipo de Propiedad_store                          -0.000929         -0.000929
#
#                                      Tipo de Propiedad_apartment  \
# Precio Metro Cuadrado                                   0.020391
# Precio                                                 -0.169955
# Ambientes                                              -0.404762
# Superficie Cubierta                                    -0.061183
# Superficie Total                                       -0.082758
# Localidad_Abasto                                        0.013714
# Localidad_Achiras                                      -0.004267
# Localidad_Agronomía                                     0.005181
# Localidad_Agua Blanca                                  -0.004267
# Localidad_Agua de Oro                                  -0.006034
# Localidad_Aguas Verdes                                 -0.007588
# Localidad_Aldea Brasilera                              -0.004267
# Localidad_Alejandro Roca                               -0.004267
# Localidad_Almafuerte                                   -0.004267
# Localidad_Almagro                                       0.063069
# Localidad_Almirante Brown                              -0.092812
# Localidad_Alta Gracia                                  -0.012801
# Localidad_Alvear                                       -0.004267
# Localidad_Anisacate                                    -0.010451
# Localidad_Apóstoles                                    -0.004267
# Localidad_Arequito                                      0.002747
# Localidad_Arroyo Ceibal                                -0.004267
# Localidad_Arroyo Seco                                  -0.004267
# Localidad_Ascochinga                                   -0.007390
# Localidad_Avellaneda                                    0.012836
# Localidad_Azara                                        -0.004267
# Localidad_Azul                                         -0.007603
# Localidad_Bahía Blanca                                 -0.002678
# Localidad_Balcarce                                     -0.017885
# Localidad_Balvanera                                     0.055123
# ...                                                          ...
# Localidad_Villa Llao Llao                              -0.004267
# Localidad_Villa Los Aromos                             -0.006034
# Localidad_Villa Lugano                                 -0.015435
# Localidad_Villa Luro                                    0.027561
# Localidad_Villa María                                  -0.003267
# Localidad_Villa Mercedes                               -0.004267
# Localidad_Villa Nueva                                  -0.004267
# Localidad_Villa Ortuzar                                 0.013164
# Localidad_Villa Paranacito                             -0.004267
# Localidad_Villa Parque Santa Ana                       -0.007390
# Localidad_Villa Parque Siquiman                        -0.004267
# Localidad_Villa Pueyrredón                              0.001100
# Localidad_Villa Real                                   -0.016252
# Localidad_Villa Riachuelo                              -0.006404
# Localidad_Villa Rumipal                                -0.007588
# Localidad_Villa Santa Cruz del Lago                    -0.009589
# Localidad_Villa Santa Rita                             -0.002721
# Localidad_Villa Soldati                                 0.000179
# Localidad_Villa Urquiza                                 0.070274
# Localidad_Villa de Las Rosas                           -0.007390
# Localidad_Villa de Soto                                -0.006034
# Localidad_Villa del Dique                              -0.013493
# Localidad_Villa del Parque                              0.025180
# Localidad_Villa del Totoral                            -0.007390
# Localidad_Wenceslao Escalante                          -0.004267
# Localidad_Yerba Buena                                  -0.010731
# Localidad_Zárate                                       -0.014781
# Tipo de Propiedad_apartment                             1.000000
# Tipo de Propiedad_house                                -0.877622
# Tipo de Propiedad_store                                -0.097592
#
#                                      Tipo de Propiedad_house  \
# Precio Metro Cuadrado                              -0.022902
# Precio                                              0.198212
# Ambientes                                           0.423620
# Superficie Cubierta                                 0.064409
# Superficie Total                                    0.090291
# Localidad_Abasto                                   -0.020723
# Localidad_Achiras                                   0.004862
# Localidad_Agronomía                                -0.012277
# Localidad_Agua Blanca                               0.004862
# Localidad_Agua de Oro                               0.006875
# Localidad_Aguas Verdes                              0.005971
# Localidad_Aldea Brasilera                           0.004862
# Localidad_Alejandro Roca                            0.004862
# Localidad_Almafuerte                                0.004862
# Localidad_Almagro                                  -0.067888
# Localidad_Almirante Brown                           0.101029
# Localidad_Alta Gracia                               0.014585
# Localidad_Alvear                                    0.004862
# Localidad_Anisacate                                 0.011909
# Localidad_Apóstoles                                 0.004862
# Localidad_Arequito                                 -0.002411
# Localidad_Arroyo Ceibal                             0.004862
# Localidad_Arroyo Seco                               0.004862
# Localidad_Ascochinga                                0.008421
# Localidad_Avellaneda                               -0.023667
# Localidad_Azara                                     0.004862
# Localidad_Azul                                      0.009461
# Localidad_Bahía Blanca                              0.008914
# Localidad_Balcarce                                  0.020011
# Localidad_Balvanera                                -0.057152
# ...                                                      ...
# Localidad_Villa Llao Llao                           0.004862
# Localidad_Villa Los Aromos                          0.001733
# Localidad_Villa Lugano                              0.000167
# Localidad_Villa Luro                               -0.034591
# Localidad_Villa María                               0.004366
# Localidad_Villa Mercedes                            0.004862
# Localidad_Villa Nueva                               0.004862
# Localidad_Villa Ortuzar                            -0.016006
# Localidad_Villa Paranacito                          0.004862
# Localidad_Villa Parque Santa Ana                    0.008421
# Localidad_Villa Parque Siquiman                     0.004862
# Localidad_Villa Pueyrredón                         -0.014143
# Localidad_Villa Real                               -0.007195
# Localidad_Villa Riachuelo                           0.001114
# Localidad_Villa Rumipal                             0.008940
# Localidad_Villa Santa Cruz del Lago                 0.011180
# Localidad_Villa Santa Rita                         -0.006832
# Localidad_Villa Soldati                            -0.002642
# Localidad_Villa Urquiza                            -0.074532
# Localidad_Villa de Las Rosas                        0.008421
# Localidad_Villa de Soto                             0.006875
# Localidad_Villa del Dique                           0.015375
# Localidad_Villa del Parque                         -0.034408
# Localidad_Villa del Totoral                         0.008421
# Localidad_Wenceslao Escalante                       0.004862
# Localidad_Yerba Buena                               0.012643
# Localidad_Zárate                                    0.016842
# Tipo de Propiedad_apartment                        -0.877622
# Tipo de Propiedad_house                             1.000000
# Tipo de Propiedad_store                            -0.055146
#
#                                      Tipo de Propiedad_store
# Precio Metro Cuadrado                               0.020422
# Precio                                              0.049980
# Ambientes                                          -0.019145
# Superficie Cubierta                                 0.023969
# Superficie Total                                    0.013181
# Localidad_Abasto                                    0.002055
# Localidad_Achiras                                  -0.000268
# Localidad_Agronomía                                 0.005602
# Localidad_Agua Blanca                              -0.000268
# Localidad_Agua de Oro                              -0.000379
# Localidad_Aguas Verdes                             -0.000657
# Localidad_Aldea Brasilera                          -0.000268
# Localidad_Alejandro Roca                           -0.000268
# Localidad_Almafuerte                               -0.000268
# Localidad_Almagro                                  -0.002495
# Localidad_Almirante Brown                           0.007638
# Localidad_Alta Gracia                              -0.000804
# Localidad_Alvear                                   -0.000268
# Localidad_Anisacate                                -0.000657
# Localidad_Apóstoles                                -0.000268
# Localidad_Arequito                                 -0.000268
# Localidad_Arroyo Ceibal                            -0.000268
# Localidad_Arroyo Seco                              -0.000268
# Localidad_Ascochinga                               -0.000464
# Localidad_Avellaneda                                0.012108
# Localidad_Azara                                    -0.000268
# Localidad_Azul                                     -0.000967
# Localidad_Bahía Blanca                             -0.004968
# Localidad_Balcarce                                 -0.001631
# Localidad_Balvanera                                -0.002831
# ...                                                      ...
# Localidad_Villa Llao Llao                          -0.000268
# Localidad_Villa Los Aromos                          0.030725
# Localidad_Villa Lugano                             -0.003384
# Localidad_Villa Luro                               -0.002606
# Localidad_Villa María                              -0.000599
# Localidad_Villa Mercedes                           -0.000268
# Localidad_Villa Nueva                              -0.000268
# Localidad_Villa Ortuzar                             0.002963
# Localidad_Villa Paranacito                         -0.000268
# Localidad_Villa Parque Santa Ana                   -0.000464
# Localidad_Villa Parque Siquiman                    -0.000268
# Localidad_Villa Pueyrredón                         -0.003458
# Localidad_Villa Real                               -0.001609
# Localidad_Villa Riachuelo                          -0.000599
# Localidad_Villa Rumipal                            -0.000657
# Localidad_Villa Santa Cruz del Lago                -0.000758
# Localidad_Villa Santa Rita                         -0.001971
# Localidad_Villa Soldati                            -0.000967
# Localidad_Villa Urquiza                            -0.005853
# Localidad_Villa de Las Rosas                       -0.000464
# Localidad_Villa de Soto                            -0.000379
# Localidad_Villa del Dique                          -0.000848
# Localidad_Villa del Parque                          0.000724
# Localidad_Villa del Totoral                        -0.000464
# Localidad_Wenceslao Escalante                      -0.000268
# Localidad_Yerba Buena                              -0.000929
# Localidad_Zárate                                   -0.000929
# Tipo de Propiedad_apartment                        -0.097592
# Tipo de Propiedad_house                            -0.055146
# Tipo de Propiedad_store                             1.000000
#
# [430 rows x 430 columns]

# %%
model =LinearRegression(fit_intercept = True)
modelRidge=Ridge()
modelLasso=Lasso()
y = df_dummies['Precio Metro Cuadrado']
X = df_dummies.drop(columns=['Precio Metro Cuadrado','Pais','Barrio','Provincia'])
Xtrain,Xtest,ytrain,ytest= train_test_split(X,y,\
                                     random_state=1)

# %%
Xtrain.shape,ytrain.shape
# Out:
# ((63988, 429), (63988,))

# %%
Xtest.shape,ytest.shape
# Out:
# ((21330, 429), (21330,))

# %%
model.fit(Xtrain,ytrain)
modelRidge.fit(Xtrain,ytrain)
modelLasso.fit(Xtrain,ytrain)
# Out:
# Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
model.intercept_
# Out:
# 1112.4821214004326

# %%
df_coef=pd.DataFrame(model.coef_).T
df_coef.columns = df_dummies.drop(columns=['Precio Metro Cuadrado','Pais','Barrio','Provincia']).columns

# %%
df_coef
# Out:
#      Precio   Ambientes  Superficie Cubierta  Superficie Total  \
# 0  0.004552 -174.971275            -0.580383         -0.093343
#
#    Localidad_Abasto  Localidad_Achiras  Localidad_Agronomía  \
# 0        308.385717      -3.374145e+08           623.653572
#
#    Localidad_Agua Blanca  Localidad_Agua de Oro  Localidad_Aguas Verdes  ...  \
# 0             -60.515918             101.402819              -265.14159  ...
#
#    Localidad_Villa de Soto  Localidad_Villa del Dique  \
# 0               139.776809                 537.062571
#
#    Localidad_Villa del Parque  Localidad_Villa del Totoral  \
# 0                 1253.767184                  -315.501268
#
#    Localidad_Wenceslao Escalante  Localidad_Yerba Buena  Localidad_Zárate  \
# 0                     344.514469            -755.119345       3273.555537
#
#    Tipo de Propiedad_apartment  Tipo de Propiedad_house  \
# 0                   535.904743              -335.887554
#
#    Tipo de Propiedad_store
# 0              3706.853358
#
# [1 rows x 429 columns]

# %%
ypred=model.predict(Xtest)
ypredRidge=modelRidge.predict(Xtest)
ypredLasso=modelLasso.predict(Xtest)

# %%
print('Lineal: ',metrics.r2_score(ytest,ypred))
print('Ridge: ',metrics.r2_score(ytest,ypredRidge))
print('Lasso: ',metrics.r2_score(ytest,ypredLasso))
# Out:
# Lineal:  -12464.0043924213
# Ridge:  0.013151087839319175
# Lasso:  0.013119863123321474
