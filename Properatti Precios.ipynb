# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
import re
# %matplotlib inline

# %%
#activar intellisense
# %config IPCompleter.greedy=True

# %%
## Importación Dataset

# %%
df = pd.read_csv('properatti.csv', index_col = 0) ### Dataset Completo
## DataFrame Partido en distintas partes relevantes
df_posicion_geografica = df.loc[:,['place_name','state_name','country_name','place_with_parent_names' \
                                   ,'geonames_id','lat','lon','lat-lon', \
                                   'describe','title']] ### Parte con Posición Geográfica
df_localidad=df.loc[:,['place_name','place_with_parent_names','describe','title']] ## Parte con Localidades
df_ambientes = df.loc[:,['rooms','property_type','description','title']]  ## Parte con Ambientes
df_pisos = df.loc[:,['floor','property_type','description','title']]  ## Parte con Pisos
df_precio = df.loc[:,['price','currency','price_aprox_local_currency','price_aprox_usd',\
                      'surface_total_in_m2','surface_covered_in_m2','price_usd_per_m2',\
                      'price_per_m2','description','title','place_name','property_type','state_name']]  ## Parte con Precios y Superficies
# Out:
# C:\Users\zelru\Anaconda3\lib\site-packages\pandas\core\indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
##Funciones

# %%
def update(df,column,s):
    '''
    Reemplaza los valores de la columna del DataFrame con
    los valores no nulos de la serie
    '''
    df[column]=s.fillna(df[column])
    return df

def busqueda_ambientes(x):
    '''
    Busca la palabra amb (de ambientes) y devuelve el número que tiene por delante
    '''
    try:
        pattern = '(\d+)\s*amb'
        regex = re.compile(pattern, flags = re.IGNORECASE | re.UNICODE)
        m = regex.search(x)
        if m:
            return float(m.group(1))
        else:
            return np.NaN
    except:
        return np.NaN

def busqueda_monoambientes(x):
    '''
    Busca en la palabra monoambiente y devuelve 1
    '''
    if type(x) is str:
        if x.lower().find('monoambiente') >-1:
            return 1

def busqueda_moneda(x):
    try:
        pattern = 'U\$D\s*([\d\.]+)'
        regex = re.compile(pattern, flags = re.IGNORECASE | re.UNICODE)
        m = regex.search(x)
        if m:
            return float(m.group(1).replace('.',''))
        else:
            np.NaN
    except:
        return np.NaN
    
def busqueda_dolar(x):
    try:
        pattern = '^\b[a-zA-Z](?!.*U\$d).\b[a-zA-Z].(?:- ?)?(?<!\d[.,]?)(?:\d{4,}|\d{1,3}(?:\.\d{3})*)(?:,\d+)?(?![.,]?\d)'
        regex = re.compile(pattern, flags = re.IGNORECASE | re.UNICODE)
        m = regex.search(x)
        if m:
            return float(m.group(1).replace('.',''))
        else:
            np.NaN
    except:
        return np.NaN
    
def parsear_numeros(x):
    '''
    Reemplaza numeros escritos en letras por sus equivalentes
    en arábigos.
    '''
    try:
        numeros={'uno':1,'un':1,'una':1,'dos':2,'tres':3,'cuatro':4,'cinco':5,'seis':6,'siete':7,'ocho':8,'nueve':9,'diez':10}
        for key in numeros:
            x = x.lower()
            x=x.replace(key,str(numeros[key]))
        return x
    except:
        return x

def busqueda_por_texto(x):
    '''
    Busca palabras claves asociadas a ambientes, como dormitorio, comedor, living, etc.
    y devuelve el número de veces que estas aparecen.
    '''
    result = 0.0
    valor = 0.0
    try:
        pattern = r"(\d*\s*living\s*cocina\s*comedor|living\s*comedor|living)|(\d*\s*dormitorio)|(\d*\s*comedor)"
        regex = re.compile(pattern, flags = re.IGNORECASE | re.UNICODE)
        grupos = regex.findall(x)
        for grupo in grupos:
            for elemento in grupo:
                regex_dos = re.compile(r'(\d+)', flags = re.IGNORECASE | re.UNICODE)
                cantidad = regex_dos.search(elemento)
                if cantidad is not None:
                    valor+=float(cantidad.group())
            if result == valor:
                result+=1
                valor+=1
            else:
                result=valor
        if result > 0.0:
            return result
        else:
            return np.NaN
    except:
        return np.NaN
def convert_to_int(x):
    return int(x)

# %%
df_precio = update(df_precio,'price',df_precio.title.apply(busqueda_moneda))

# %%
df_precio.pivot_table(('price_aprox_usd'),columns=['property_type'],
                      fill_value=0,aggfunc=[np.mean])
# Out:
#                           mean
# property_type               PH      apartment          house         store
# price_aprox_usd  147689.419611  187406.880406  329696.776384  440257.06294

# %%
df_pivot=df_precio.pivot_table(('price_aprox_usd'),columns=['state_name'],
                      fill_value=0,aggfunc=[np.mean])

# %%
df_pivot.transpose()
# Out:
#                                    price_aprox_usd
#      state_name
# mean Bs.As. G.B.A. Zona Norte        324317.123170
#      Bs.As. G.B.A. Zona Oeste        167545.648499
#      Bs.As. G.B.A. Zona Sur          198555.715572
#      Buenos Aires Costa Atlántica    143430.988472
#      Buenos Aires Interior           183249.996582
#      Capital Federal                 269603.182879
#      Catamarca                       725471.707308
#      Chaco                           178583.551389
#      Chubut                          342338.181524
#      Corrientes                      206896.786681
#      Córdoba                         203624.244417
#      Entre Ríos                      148113.819692
#      Formosa                          63463.367586
#      Jujuy                           301584.442000
#      La Pampa                        111053.792222
#      La Rioja                         60954.385000
#      Mendoza                         249705.485588
#      Misiones                        121241.552299
#      Neuquén                         219429.090401
#      Río Negro                       300126.180693
#      Salta                           312755.743529
#      San Juan                        299575.820000
#      San Luis                        282242.500433
#      Santa Cruz                      176129.507895
#      Santa Fe                        139609.617118
#      Santiago Del Estero             163428.393333
#      Tierra Del Fuego                180246.755161
#      Tucumán                         158878.733192

# %%
df_precio.groupby(['price_aprox_usd']).transform('mean')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1163         try:
# -> 1164             x = float(x)
#    1165         except Exception:
#
# ValueError: could not convert string to float: 'Casa en Venta de 2 dorm. en Armenia'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1166             try:
# -> 1167                 x = complex(x)
#    1168             except Exception:
#
# ValueError: complex() arg is a malformed string
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     126                 else:
# --> 127                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     128             except Exception:
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in nanmean(values, axis, skipna, mask)
#     478     count = _get_counts(mask, axis, dtype=dtype_count)
# --> 479     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     480
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1169                 raise TypeError('Could not convert {value!s} to numeric'
# -> 1170                                 .format(value=x))
#    1171     return x
#
# TypeError: Could not convert Casa en Venta de 2 dorm. en Armenia to numeric
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1163         try:
# -> 1164             x = float(x)
#    1165         except Exception:
#
# ValueError: could not convert string to float: 'Casa en Venta de 2 dorm. en Armenia'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1166             try:
# -> 1167                 x = complex(x)
#    1168             except Exception:
#
# ValueError: complex() arg is a malformed string
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _transform_general(self, func, *args, **kwargs)
#     486                 try:
# --> 487                     path, res = self._choose_path(fast_path, slow_path, group)
#     488                 except TypeError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _choose_path(self, fast_path, slow_path, group)
#     583         path = slow_path
# --> 584         res = slow_path(group)
#     585
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in <lambda>(group)
#     574             slow_path = lambda group: group.apply(
# --> 575                 lambda x: getattr(x, func)(*args, **kwargs), axis=self.axis)
#     576         else:
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6486                          kwds=kwds)
# -> 6487         return op.get_result()
#    6488
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     150
# --> 151         return self.apply_standard()
#     152
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     256         # compute the result using the series generator
# --> 257         self.apply_series_generator()
#     258
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     285                 for i, v in enumerate(series_gen):
# --> 286                     results[i] = self.f(v)
#     287                     keys.append(v.name)
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in <lambda>(x)
#     574             slow_path = lambda group: group.apply(
# --> 575                 lambda x: getattr(x, func)(*args, **kwargs), axis=self.axis)
#     576         else:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   10955         return self._reduce(f, name, axis=axis, skipna=skipna,
# > 10956                             numeric_only=numeric_only)
#   10957
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3629             with np.errstate(all='ignore'):
# -> 3630                 return op(delegate, skipna=skipna, **kwds)
#    3631
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      75                 with np.errstate(invalid='ignore'):
# ---> 76                     return f(*args, **kwargs)
#      77             except ValueError as e:
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     129                 try:
# --> 130                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     131                 except ValueError as e:
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in nanmean(values, axis, skipna, mask)
#     478     count = _get_counts(mask, axis, dtype=dtype_count)
# --> 479     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     480
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1169                 raise TypeError('Could not convert {value!s} to numeric'
# -> 1170                                 .format(value=x))
#    1171     return x
#
# TypeError: ('Could not convert Casa en Venta de 2 dorm. en Armenia to numeric', 'occurred at index description')
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-b6c8f8fef935> in <module>
# ----> 1 df_precio.groupby(['price_aprox_usd']).transform('mean')
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in transform(self, func, *args, **kwargs)
#     544         # nuiscance columns
#     545         if not result.columns.equals(obj.columns):
# --> 546             return self._transform_general(func, *args, **kwargs)
#     547
#     548         return self._transform_fast(result, obj, func)
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _transform_general(self, func, *args, **kwargs)
#     487                     path, res = self._choose_path(fast_path, slow_path, group)
#     488                 except TypeError:
# --> 489                     return self._transform_item_by_item(obj, fast_path)
#     490                 except ValueError:
#     491                     msg = 'transform must return a scalar value for each group'
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _transform_item_by_item(self, obj, wrapper)
#     615
#     616         if len(output) == 0:  # pragma: no cover
# --> 617             raise TypeError('Transform function invalid for data types')
#     618
#     619         columns = obj.columns
#
# TypeError: Transform function invalid for data types
